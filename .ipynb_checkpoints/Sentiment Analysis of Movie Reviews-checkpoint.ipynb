# %% [markdown]
# # Sentiment Analysis of Movie Reviews

# %% [markdown]
# In this project, I attempted to classify a series of review from Rotten Tomatoes into their respective sentiments. I took the data from a Kaggle Competition with the same aim(https://www.kaggle.com/c/sentiment-analysis-on-movie-reviews/data).
#
# The winner of the competition had an accuracy of 76% with his model.

# %% [markdown]
# *************************************

# %% [markdown]
# ## Data Exploration

# %%
#Importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/core/computation/__init__.py:18: UserWarning: The installed version of numexpr 2.4.3 is not supported in pandas and will be not be used
# The minimum supported version is 2.4.6
#
#   ver=ver, min_ver=_MIN_NUMEXPR_VERSION), UserWarning)

# %%
#Loading raw data
raw_train_data =  pd.DataFrame.from_csv('train.tsv', sep='\t', header=0)
raw_train_data = raw_train_data.reset_index()

raw_train_data.head()
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
raw_train_data.sample(n=5)
# Out:
#         PhraseId  SentenceId  \
# 99513      99514        5218
# 100672    100673        5286
# 84878      84879        4389
# 73566      73567        3761
# 108927    108928        5766
#
#                                                    Phrase  Sentiment
# 99513              a dysfunctionally privileged lifestyle          2
# 100672                                              cries          2
# 84878                                          someone 's          2
# 73566                             Heavy with flabby rolls          2
# 108927  be swept up in Invincible and overlook its dra...          3

# %% [markdown]
# As we can see, the data has 4 columns,[PhraseId,SentenceId,Phrase,Sentiment]. Each sentence/review is split up into phrases and a sentiment label is attached to it.
#
# The sentiment label types are:
# - 0(Negative)
# - 1(Somewhat negative)
# - 2(Neutral)
# - 3(Somewhat positive)
# - 4(Positive)

# %%
raw_train_data.describe()
# Out:
#             PhraseId     SentenceId      Sentiment
# count  156060.000000  156060.000000  156060.000000
# mean    78030.500000    4079.732744       2.063578
# std     45050.785842    2502.764394       0.893832
# min         1.000000       1.000000       0.000000
# 25%     39015.750000    1861.750000       2.000000
# 50%     78030.500000    4017.000000       2.000000
# 75%    117045.250000    6244.000000       3.000000
# max    156060.000000    8544.000000       4.000000

# %% [markdown]
# There are a total of 156060 data points, with the average sentiment being neutral, bordering on somewhat positive.

# %%
plt.figure(figsize=(8,9))
ax=sns.countplot(x='Sentiment',data=raw_train_data)

labels = ['Negative','Somewhat Negative','Neutral','Somewhat Positive','Positive']
ax.set_xticklabels(labels)

for p in ax.patches:
    height = p.get_height()
    if(np.isnan(height)):
        height=0
    ax.text(p.get_x()+p.get_width()/2.,
            height + 3,
            height,
            ha="center")

# %% [markdown]
# The most frequent sentiment associated with reviews is 'neutral', whereas the least frequent is 'negative'.

# %%
print "Total number of sentences: " + str(raw_train_data['SentenceId'][-1:].values)
# Out:
# Total number of sentences: [8544]

# %% [markdown]
# There are a total of 8,544 reviews, which have been split up into different phrases.

# %% [markdown]
# *************************************************

# %%
from nltk.tokenize import word_tokenize

#Tokenizing the phrases
raw_train_data['Tokens'] = raw_train_data.apply(lambda row: word_tokenize(row['Phrase']), axis=1)

#Converting tokens to lower case
raw_train_data['Tokens'] = raw_train_data.apply(lambda row: map(lambda x:x.lower(),row['Tokens']),axis=1)

raw_train_data['Tokens'].head()
# Out:
# 0    [a, series, of, escapades, demonstrating, the,...
# 1    [a, series, of, escapades, demonstrating, the,...
# 2                                          [a, series]
# 3                                                  [a]
# 4                                             [series]
# Name: Tokens, dtype: object

# %% [markdown]
# I've tokenized the phrases and converted the words into lower case. Tokenizing is the process of splitting a sentence into words(or tokens). I've also converted the tokens to all lower-case in order to prevent the model from differentiating between,say, 'Annoying' and 'annoying'.

# %%
#Remove punctuation
punct = ['.',',',':','``','--','','\'s','\'','&','$','#','\'\'','`']

def punctremove(mylist):
    return [w for w in mylist if not w in punct]

raw_train_data['Tokens'] = raw_train_data.apply(lambda row: punctremove(row['Tokens']), axis=1)

# %% [markdown]
# I've removed punctuation from the tokens because they don't add any immediate sentiment to a sentence. Notice that I haven't removed punctuation like '!' and '?' which could add sentiment.

# %%
from nltk.stem import WordNetLemmatizer

#Lemmatizing tokens
lemmatizer = WordNetLemmatizer()

def lemmatizefunc(mylist):
    return [lemmatizer.lemmatize(w) for w in mylist]

raw_train_data['Tokens'] = raw_train_data.apply(lambda row: lemmatizefunc(row['Tokens']), axis=1)

raw_train_data['Tokens'].head()
# Out:
# 0    [a, series, of, escapade, demonstrating, the, ...
# 1    [a, series, of, escapade, demonstrating, the, ...
# 2                                          [a, series]
# 3                                                  [a]
# 4                                             [series]
# Name: Tokens, dtype: object

# %% [markdown]
# Lemmatizing is the process of simplifying tokens down to their base word. For example, the word 'tyres' is simplified down to 'tyre'. It is different from another process, stemming, in the way that lemmatizing leads to a simplification to an actual word, whereas stemming can simplify a word down to something which isn't an actual word.
#
# Lemmatizing will largely help in reducing the large vocabulary pool, and helping word2vec create a more robust model.

# %%
#Building a dictionary
word_list = []
for index,value in raw_train_data['Tokens'].iteritems():
    word_list.extend(value)

vocab = set(word_list)

vocab_set = sorted(vocab)

# %%
#Creating dictionary containing frequency of words
vocab_freq = dict()

for value in vocab_set:
    vocab_freq[value]=0
    
for index,item in raw_train_data['Tokens'].iteritems():
    for word in item:
        vocab_freq[word] = vocab_freq[word] + 1
        
vocab_freq
# Out:
# {'unimaginative': 58,
#  'bad-boy': 8,
#  'ryoko': 5,
#  'foul': 37,
#  'pony': 13,
#  'four': 187,
#  'clotted': 5,
#  'hanging': 17,
#  'conjuring': 8,
#  'woody': 55,
#  'genre': 427,
#  'comically': 24,
#  u'shamble': 6,
#  'conjure': 7,
#  'crooned': 4,
#  'hennings': 13,
#  'pardon': 10,
#  'unanswered': 7,
#  'originality': 87,
#  'superficially': 19,
#  'stevenon': 6,
#  'xtc': 9,
#  'lore': 21,
#  'lord': 39,
#  'immature': 24,
#  u'digit': 16,
#  u'delf': 4,
#  'pierce': 6,
#  'yellow': 28,
#  'bringing': 53,
#  'picaresque': 8,
#  'disturb': 13,
#  'sixties-style': 6,
#  'grueling': 13,
#  'wooden': 34,
#  'truck-loving': 12,
#  'karen': 18,
#  'wednesday': 14,
#  'peerlessly': 3,
#  'standout': 8,
#  'shouting': 11,
#  'geeked': 7,
#  'stereotypical': 46,
#  'eye-popping': 17,
#  'straight': 172,
#  u'fritter': 11,
#  'sprung': 15,
#  'sturm': 13,
#  'less-is-more': 7,
#  'insular': 3,
#  'big-wave': 14,
#  'miller': 46,
#  'bacon': 16,
#  'pulse': 34,
#  '270': 7,
#  'elegant': 64,
#  'second': 247,
#  'crisply': 3,
#  u'shelf': 68,
#  'shrugging': 23,
#  'sterile': 7,
#  'quite': 545,
#  'hilariously': 21,
#  'nonsense': 41,
#  'hit-man': 10,
#  'reopens': 9,
#  'ruthless': 16,
#  'contributed': 9,
#  u'schmuck': 7,
#  'videodrome': 7,
#  'cross-cultural': 6,
#  'sneering': 3,
#  'negated': 5,
#  'contributes': 7,
#  u'groupie': 7,
#  'succumb': 29,
#  'submerged': 9,
#  'insinuation': 10,
#  u'hero': 252,
#  'avert': 7,
#  'grenier': 2,
#  'intentioned': 12,
#  'divertissement': 9,
#  'brit-com': 5,
#  'here': 585,
#  'reported': 8,
#  'china': 58,
#  'kissing': 14,
#  'cult': 82,
#  'shriek': 13,
#  'conversational': 5,
#  'transfixes': 7,
#  'substance': 151,
#  'uplifting': 56,
#  'unwillingness': 2,
#  'elaborate': 60,
#  'gone-to-seed': 10,
#  'controversy': 37,
#  'grade-school': 11,
#  'kidd': 5,
#  'karim': 8,
#  'dimness': 14,
#  'military': 20,
#  'shmear': 17,
#  'spotty': 5,
#  'shallower': 8,
#  'missing': 94,
#  'pee-related': 10,
#  'criticism': 20,
#  'appropriately': 9,
#  'gainsbourg': 12,
#  'classification': 9,
#  'sweetest': 10,
#  'reenactment': 5,
#  'lynne': 6,
#  'brought': 83,
#  'underrated': 13,
#  'shoddy': 26,
#  'wizardry': 13,
#  'stern': 7,
#  'resonant': 67,
#  u'obligation': 20,
#  'scarier': 19,
#  'ominous': 18,
#  'best-selling': 16,
#  'cannibal': 15,
#  'music': 552,
#  u'telegraph': 5,
#  'mystic': 18,
#  'strike': 103,
#  'do-over': 9,
#  'playboy': 10,
#  'borstal': 6,
#  'standardized': 9,
#  'holy': 20,
#  'cineasts': 2,
#  'brings': 115,
#  'mesmerize': 8,
#  'hereby': 5,
#  'whirling': 10,
#  'gunplay': 15,
#  'hurt': 55,
#  '99': 12,
#  '98': 4,
#  'holm': 45,
#  'goddammit': 12,
#  '90': 153,
#  '93': 10,
#  u'echelon': 14,
#  '95': 15,
#  '94': 13,
#  '96': 5,
#  'crossing-over': 13,
#  'morally': 41,
#  'virtuous': 11,
#  'huppert': 34,
#  'pursue': 7,
#  'self-styled': 7,
#  'famed': 4,
#  u'accomplishment': 37,
#  'wade': 29,
#  'straddle': 15,
#  'example': 76,
#  'expressively': 4,
#  'triple': 11,
#  'superbly': 20,
#  u'wane': 19,
#  u'household': 21,
#  'beautifully': 223,
#  'organized': 9,
#  'peppering': 12,
#  'recoing': 4,
#  'bluescreen': 20,
#  u'caution': 9,
#  'want': 588,
#  'gargantuan': 12,
#  'absolute': 34,
#  'preferably': 11,
#  'oliveira': 2,
#  'poverty': 58,
#  'tchaikovsky': 7,
#  'complaining': 9,
#  'travel': 47,
#  'drying': 13,
#  'copious': 6,
#  'machine': 118,
#  u'groaner': 12,
#  'flesh-and-blood': 18,
#  'well-constructed': 15,
#  'dangerfield': 3,
#  'hop': 18,
#  'significance': 29,
#  'double-barreled': 13,
#  'place': 553,
#  'passive-aggressive': 10,
#  'preferable': 8,
#  u'cadence': 20,
#  'uncinematic': 12,
#  'paste': 13,
#  'beauty': 219,
#  'funny': 1522,
#  'assimilated': 6,
#  'survivable': 16,
#  'blood-splattering': 6,
#  'modest': 88,
#  'barney': 30,
#  'destined': 18,
#  'turf': 30,
#  'chump': 14,
#  'steadfast': 8,
#  'colorfully': 3,
#  'effective': 126,
#  'attracts': 8,
#  'fleetingly': 9,
#  'fictional': 21,
#  'teleprompter': 11,
#  'sickening': 30,
#  'baggage': 34,
#  'shocker': 20,
#  'democratic': 6,
#  'nonsensical': 27,
#  'waldo': 13,
#  u'backdrop': 46,
#  u'wine': 11,
#  'sprawling': 11,
#  'bug-eyed': 17,
#  'welcomed': 10,
#  'derring-do': 8,
#  'misdemeanor': 12,
#  'vary': 8,
#  'wonder-what': 7,
#  'sunshine': 13,
#  'rewarded': 18,
#  'wrought': 4,
#  'impossibly': 14,
#  'admirably': 21,
#  'conned': 22,
#  'lovingly': 13,
#  'fit': 166,
#  'heretofore': 9,
#  'fix': 31,
#  'stevens': 16,
#  'intelligentsia': 15,
#  'distinguishing': 9,
#  'oh-so': 17,
#  'insubstantial': 11,
#  'accentuating': 7,
#  'hidden': 26,
#  'admirable': 85,
#  'easier': 52,
#  'fil': 7,
#  'spy-thriller': 4,
#  'perkiness': 9,
#  'undercut': 48,
#  'girl-buddy': 9,
#  'grievous': 12,
#  'sinuously': 7,
#  'vainglorious': 10,
#  'zoning': 7,
#  'detachment': 7,
#  'kiddie-oriented': 4,
#  'low-tech': 7,
#  'eisenhower': 10,
#  'ebullient': 16,
#  'represents': 68,
#  'soullessness': 8,
#  'clobbering': 17,
#  'merrily': 6,
#  'whacking': 9,
#  'softens': 9,
#  'debut': 287,
#  'disconnection': 4,
#  'arrow': 15,
#  'two-bit': 2,
#  'addicted': 8,
#  'volcano': 18,
#  'interfering': 5,
#  'unwary': 10,
#  'preceded': 17,
#  'dolphin-gasm': 10,
#  'swathe': 10,
#  'woo': 68,
#  'knockout': 20,
#  'series': 363,
#  'long-running': 6,
#  'displacement': 6,
#  'solution': 44,
#  'yiddish': 42,
#  '2,500': 11,
#  'ages-old': 15,
#  'knitting': 7,
#  'rarest': 11,
#  'whir': 10,
#  'ring': 94,
#  'whip': 10,
#  'fifteen-year-old': 13,
#  'misfortune': 11,
#  'workaday': 11,
#  'diction': 9,
#  'oprah': 18,
#  'pokemon': 45,
#  u'ha': 2950,
#  'excepting': 14,
#  'pollyana': 5,
#  'mason': 10,
#  're': 3,
#  'encourage': 13,
#  u'vector': 7,
#  'heavy-duty': 6,
#  'zap': 9,
#  u'mend': 11,
#  u'outburst': 22,
#  'smart': 326,
#  'dust-caked': 13,
#  'abbott': 13,
#  'assured': 70,
#  'written': 224,
#  '21\\/2': 13,
#  'pauline': 27,
#  'fugitive': 7,
#  'yesterday': 45,
#  'assures': 6,
#  'necessarily': 47,
#  'encountering': 13,
#  'nice': 165,
#  'stacy': 8,
#  '9-11': 19,
#  'howlingly': 11,
#  'silbersteins': 12,
#  'enormous': 40,
#  'ate': 10,
#  'bates': 12,
#  'exposing': 7,
#  'sensational': 42,
#  'sickeningly': 11,
#  'washout': 9,
#  'dramatically': 62,
#  'run-on': 12,
#  'family-friendly': 19,
#  'speedy': 17,
#  'naturalism': 21,
#  'tempting': 28,
#  '1970s': 31,
#  '95-minute': 11,
#  'unflappable': 14,
#  'thankless': 17,
#  'stripe': 8,
#  'elmo': 2,
#  'wasp': 14,
#  'subtlety': 74,
#  'playfully': 7,
#  u'veggie': 17,
#  'dark-as-pitch': 5,
#  'instruct': 8,
#  'movie-biz': 6,
#  'clamorous': 18,
#  'clarity': 98,
#  '170': 19,
#  'bitten': 8,
#  'basketball': 33,
#  'service': 95,
#  'similarly': 51,
#  'tired': 192,
#  'disease-of': 13,
#  'needed': 90,
#  'theatrically': 17,
#  'unexplainable': 22,
#  'master': 154,
#  'switchblade': 14,
#  'tick-tock': 6,
#  'bitter': 87,
#  'genesis': 9,
#  'hewitt': 33,
#  'danish': 11,
#  u'collapse': 38,
#  'enthrall': 7,
#  'predictably': 54,
#  'wide-smiling': 11,
#  'stake': 24,
#  'satisfaction': 9,
#  'wisdom': 25,
#  'task': 35,
#  'predictable': 308,
#  'masala': 4,
#  'zany': 24,
#  'crawl': 20,
#  'positively': 38,
#  'trek': 65,
#  u'peril': 33,
#  'hubristic': 8,
#  'iteration': 5,
#  'likely': 260,
#  'project': 307,
#  'endure': 56,
#  'maik': 11,
#  'feeling': 321,
#  'seduced': 7,
#  'unintended': 6,
#  'acclaim': 20,
#  'shadowy': 26,
#  'willingness': 29,
#  'exploring': 44,
#  'runner': 34,
#  'boston': 13,
#  'wealth': 4,
#  'spectrum': 18,
#  'glass': 86,
#  'spent': 91,
#  'quasi-shakespearean': 11,
#  'brawny': 23,
#  'corny': 53,
#  'constricted': 5,
#  'tale': 590,
#  'dozen': 59,
#  'wholesome': 38,
#  'concrete': 11,
#  'mothman': 38,
#  'responsible': 39,
#  'self-flagellation': 4,
#  'larky': 20,
#  'recommended': 34,
#  'absorbed': 12,
#  'amusing': 321,
#  'pop-culture': 14,
#  'sweet-tempered': 6,
#  'pander': 9,
#  'baseball-playing': 8,
#  'reverberates': 4,
#  'thrilled': 6,
#  'mystique': 7,
#  'diminishing': 16,
#  'vexing': 7,
#  'cinematic': 380,
#  u'encomium': 11,
#  'disjointed': 24,
#  'mouth': 62,
#  'addict': 17,
#  'letter': 25,
#  'retaining': 8,
#  'lip-gloss': 14,
#  'hide-and-seek': 11,
#  'thriller': 637,
#  'miscalculates': 5,
#  'expound': 10,
#  u'dummy': 21,
#  'singer': 21,
#  'kouyate': 22,
#  'episode': 195,
#  'antitrust': 14,
#  u'professor': 23,
#  'camp': 106,
#  'lie': 89,
#  'stand-up-comedy': 8,
#  'consummate': 14,
#  'leone': 9,
#  'world-at-large': 19,
#  'detriment': 21,
#  'pretty': 415,
#  u'scream': 63,
#  'came': 56,
#  'classicism': 12,
#  'incorporate': 20,
#  'chirpy': 3,
#  u'bomb': 22,
#  'tequila': 13,
#  'seduces': 8,
#  'nominated': 10,
#  'utterly': 129,
#  'direct-to-video\\/dvd': 10,
#  'uruk-hai': 6,
#  'gauge': 7,
#  'hazy': 10,
#  'participate': 14,
#  'rediscovers': 7,
#  'hard-to-predict': 11,
#  'fixating': 21,
#  'caper': 44,
#  'orleans': 10,
#  'busy': 36,
#  'lethargically': 4,
#  'itinerant': 8,
#  'quaint': 9,
#  'menu': 9,
#  'pop-influenced': 12,
#  'louiso': 6,
#  u'bust': 14,
#  'kozmo': 10,
#  'bush': 17,
#  'assaultive': 8,
#  'bliss': 12,
#  'rick': 8,
#  'parodied': 9,
#  u'telegram': 17,
#  'heartily': 13,
#  'rice': 48,
#  u'plate': 28,
#  'trance-noir': 6,
#  'godzilla': 12,
#  'culkin': 16,
#  'plato': 10,
#  'foremost': 16,
#  'pocket': 10,
#  'savoca': 7,
#  'clumsiness': 6,
#  'cushion': 11,
#  'altogether': 44,
#  'tyco': 8,
#  'relish': 7,
#  'unfortunately': 58,
#  'droning': 12,
#  'profoundly': 26,
#  u'avenger': 9,
#  'autistic': 8,
#  'nicely': 98,
#  u'boarder': 4,
#  u'rumbling': 8,
#  'hotel': 48,
#  'greene': 41,
#  'qatsi': 20,
#  'stunningly': 21,
#  'release': 141,
#  'shiver-inducing': 10,
#  'creepy-scary': 9,
#  'bleu': 8,
#  'traverse': 19,
#  'disaster': 86,
#  'fair': 70,
#  'ill-wrought': 8,
#  'unfussily': 13,
#  'sensitivity': 57,
#  'twinkling': 8,
#  'evolving': 8,
#  'widget': 13,
#  'unexpectedly': 40,
#  'bled': 10,
#  'expedience': 19,
#  u'result': 141,
#  'follow-your-dream': 12,
#  'fail': 36,
#  'wait': 101,
#  'hammer': 23,
#  'best': 1059,
#  'moron': 8,
#  'eudora': 11,
#  'playfulness': 11,
#  'deadpan': 41,
#  'ackerman': 4,
#  u'reporter': 8,
#  'cosby-seinfeld': 6,
#  'suge': 8,
#  'irk': 11,
#  'humankind': 12,
#  'markedly': 7,
#  'offering': 89,
#  'conceptual': 21,
#  'occupational': 8,
#  u'ooze': 11,
#  u'preserve': 7,
#  'letting': 53,
#  'screwball': 39,
#  'never': 1114,
#  'nationwide': 18,
#  'nature': 217,
#  'rolled': 8,
#  'wise-beyond-her-years': 6,
#  'lapping': 10,
#  'superficial': 95,
#  'inextricably': 7,
#  'schoolboy': 9,
#  'tashlin': 14,
#  'rude': 47,
#  'conflagration': 13,
#  'defiance': 21,
#  'angling': 8,
#  'roller': 11,
#  'pity': 60,
#  'dysfunctionally': 13,
#  'accident': 17,
#  'trickster': 15,
#  'sacrificing': 26,
#  'disdain': 14,
#  'country': 155,
#  'inner-city': 42,
#  u'secretion': 13,
#  'planned': 12,
#  'lookin': 8,
#  'logic': 72,
#  'argue': 45,
#  'adapted': 35,
#  'asked': 6,
#  'fearlessly': 6,
#  'diciness': 6,
#  'shapiro': 11,
#  'fudged': 9,
#  'irresponsible': 31,
#  'outer-space': 13,
#  'blutarsky': 3,
#  'dorm': 10,
#  'staggering': 6,
#  'blending': 6,
#  'pregnancy': 8,
#  'bollywood\\/hollywood': 4,
#  u'blonde': 22,
#  'truthful': 33,
#  'sense-of-humour': 6,
#  'smackdown': 4,
#  'toolbags': 4,
#  'pantheon': 38,
#  'yale': 13,
#  'cardboard': 17,
#  'milquetoast': 12,
#  'billing': 8,
#  'eckstraordinarily': 3,
#  'disgracefully': 7,
#  'tree': 51,
#  'advert': 5,
#  'unsalvageability': 6,
#  'much': 1862,
#  'makhmalbaf': 13,
#  'decades-spanning': 7,
#  'undistinguished': 12,
#  'superhuman': 17,
#  'jackass': 27,
#  'proficiently': 4,
#  'incompetent': 46,
#  'cub': 10,
#  'doldrums': 6,
#  'life': 1862,
#  'headly': 5,
#  u'spit': 17,
#  'eastern': 26,
#  'uni-dimensional': 8,
#  'courtney': 4,
#  'worker': 32,
#  u'davy': 17,
#  'filmmaker': 576,
#  'relevance': 23,
#  'dave': 7,
#  u'lift': 59,
#  u'child': 460,
#  'oh-so-important': 7,
#  'spin': 67,
#  'modern-day': 22,
#  u'chill': 80,
#  'commerce': 23,
#  'gritty': 60,
#  'participatory': 11,
#  'cheapened': 12,
#  'willis': 43,
#  'transfigures': 17,
#  'roland': 1,
#  'meddles': 18,
#  'suitably': 16,
#  'castro': 37,
#  'sinise': 6,
#  'employ': 30,
#  'contemplates': 4,
#  'misconstrued': 12,
#  'surprised': 36,
#  'visit': 48,
#  'harvesting': 16,
#  'reunion': 47,
#  'k': 3,
#  'remembering': 44,
#  'ridiculously': 11,
#  'majid': 12,
#  'spoof': 62,
#  'played': 68,
#  'hatfield': 8,
#  'hard-driving': 9,
#  'letdown': 13,
#  'characterize': 11,
#  'elicit': 15,
#  'upscale': 17,
#  'madonna': 48,
#  'throwing': 49,
#  'specter': 6,
#  'subliminally': 11,
#  'damaged': 41,
#  'lushly': 4,
#  'hokey': 18,
#  'jolting': 9,
#  'cumulative': 14,
#  'doofus': 20,
#  'rebellion': 27,
#  'spews': 12,
#  'haphazard': 18,
#  'electra': 15,
#  'zoolander': 8,
#  'thinly': 20,
#  'stadium-seat': 14,
#  'superman': 24,
#  'emphatic': 6,
#  'european': 34,
#  'fairly': 215,
#  'boiled': 7,
#  'effortlessly': 38,
#  'inadvertently': 14,
#  'virtuosity': 10,
#  'captivates': 13,
#  'middle-aged': 61,
#  'sports-movie': 8,
#  'toback': 35,
#  'preachy': 68,
#  'ownership': 12,
#  'sissako': 6,
#  'featherweight': 3,
#  u'tune': 25,
#  'wimmer': 8,
#  'suitable': 20,
#  'lucas': 18,
#  'intrusion': 9,
#  'academic': 17,
#  u'relay': 7,
#  'undercurrent': 26,
#  'backhanded': 11,
#  'corporate': 23,
#  'cipherlike': 8,
#  'near-impossible': 7,
#  'eroticism': 6,
#  'joshua': 1,
#  'benshan': 11,
#  'letterman': 18,
#  'golden': 24,
#  'smashups': 9,
#  'forsaken': 10,
#  'deadeningly': 8,
#  'disguise': 57,
#  'birmingham': 12,
#  'stultifyingly': 12,
#  'plight': 40,
#  'overly-familiar': 15,
#  'sprecher': 15,
#  'previous': 182,
#  'retitle': 12,
#  'enters': 20,
#  'hal': 30,
#  'ham': 25,
#  'lunacy': 39,
#  'ease': 30,
#  'asiaphiles': 6,
#  'had': 674,
#  'fresh-faced': 19,
#  'genevieve': 10,
#  'macdonald': 9,
#  'topical': 28,
#  'beloved': 24,
#  'prison': 56,
#  u'falter': 8,
#  'over-amorous': 10,
#  'east': 25,
#  'espoused': 8,
#  'drably': 11,
#  'unblinkingly': 7,
#  'self-inflicted': 6,
#  u'quirk': 66,
#  'confection': 8,
#  'wewannour': 6,
#  'obscenity': 10,
#  'possible': 205,
#  'firmer': 9,
#  'unequivocally': 12,
#  'posey': 7,
#  'rocket': 33,
#  'otherworldly': 26,
#  'indicative': 14,
#  'sorority': 25,
#  'unlikely': 81,
#  'pertinent': 31,
#  u'shadow': 92,
#  'replace': 11,
#  'tolerable': 8,
#  u'stylist': 20,
#  u'desire': 107,
#  'elude': 16,
#  'uncouth': 7,
#  u'specie': 11,
#  'tuxedo': 28,
#  'grand-scale': 7,
#  'seaside': 5,
#  'alice': 46,
#  'crematorium': 6,
#  'remind': 32,
#  'articulates': 9,
#  'well-paced': 8,
#  'prologue': 12,
#  'grotesquely': 9,
#  'battlefield': 27,
#  'right': 577,
#  'old': 691,
#  'creek': 22,
#  'crowd': 143,
#  'people': 1073,
#  'macabre': 19,
#  'creed': 16,
#  'mumbo-jumbo': 9,
#  'topping': 6,
#  'captive': 13,
#  'sure': 231,
#  'insistence': 14,
#  'trombone': 10,
#  u'creep': 27,
#  'comeuppance': 12,
#  'vibrance': 9,
#  'for': 7417,
#  'bottom': 72,
#  'inhuman': 14,
#  'creative': 183,
#  'witty': 119,
#  'flopping': 10,
#  'exposition': 46,
#  u'landscape': 110,
#  'oliviera': 10,
#  'foo': 9,
#  'theological': 4,
#  'cultist': 9,
#  'palatable': 20,
#  'wackiness': 10,
#  u'energy': 346,
#  'skit-com': 5,
#  'krawczyk': 10,
#  'shifting': 26,
#  'defensive': 9,
#  'losing': 58,
#  'memorable': 215,
#  'shaken': 24,
#  'transcends': 37,
#  'derailed': 14,
#  'augmented': 7,
#  'o': 40,
#  'alexandre': 18,
#  'bicentennial': 9,
#  'despair': 76,
#  'repellent': 20,
#  'surveillance': 17,
#  'stoked': 14,
#  'insecurity': 11,
#  'importantly': 9,
#  'lacked': 9,
#  u'observation': 116,
#  'slightly': 136,
#  'emilie': 9,
#  'nixon': 13,
#  'raised': 38,
#  'marshall': 22,
#  'respectably': 9,
#  'saddle': 17,
#  'near-hypnotic': 8,
#  'respectable': 66,
#  'plot-lines': 6,
#  u'wrap': 19,
#  'hallucinogenic': 11,
#  'reducing': 9,
#  'frazzled': 10,
#  'appealingly': 7,
#  'retro-refitting': 13,
#  'lunar': 8,
#  'suffice': 5,
#  'constantly': 42,
#  'knowing': 88,
#  'mullan': 10,
#  'uncluttered': 6,
#  'humorous': 87,
#  'grasping': 8,
#  'greatness': 29,
#  'jane': 32,
#  'fabuleux': 4,
#  'happy': 122,
#  'underestimated': 18,
#  'insurrection': 4,
#  'non-stop': 18,
#  'pointless': 112,
#  u'offer': 428,
#  'fascination': 18,
#  'forming': 8,
#  'co-writer': 42,
#  'melanie': 13,
#  'understandable': 13,
#  'yo': 3,
#  'unshapely': 8,
#  'underdeveloped': 4,
#  'duel': 7,
#  'circumstantial': 18,
#  'silliness': 60,
#  'masquerading': 5,
#  u'extremity': 8,
#  'myopic': 13,
#  'inside': 235,
#  'bouncy': 15,
#  'until': 126,
#  'epps': 16,
#  'nicest': 20,
#  'torturing': 10,
#  'rerun': 44,
#  'mighty': 7,
#  'recalling': 7,
#  'minac': 6,
#  'juvenile': 56,
#  'later': 51,
#  'disgrace': 8,
#  'barrymore': 28,
#  'percolating': 9,
#  'out-shock': 10,
#  'as-it': 10,
#  'proven': 15,
#  'tear-drenched': 7,
#  'soothe': 11,
#  'ribcage': 11,
#  'exist': 31,
#  u'dealer': 46,
#  'redolent': 15,
#  u'leer': 5,
#  'heartbreakingly': 21,
#  'dotted': 8,
#  'floor': 36,
#  u'actor': 859,
#  'one-joke': 8,
#  'flood': 8,
#  'deep-seated': 16,
#  'kirshner': 11,
#  'ambitious': 186,
#  'wreaked': 10,
#  'french-produced': 8,
#  'smell': 11,
#  'roll': 83,
#  'wending': 5,
#  'woodman': 7,
#  'double-cross': 7,
#  'outage': 10,
#  'stealing': 39,
#  'devos': 8,
#  'transported': 8,
#  'too-long': 8,
#  "'d": 293,
#  'intent': 38,
#  'scuzzy': 12,
#  'rolling': 34,
#  "'n": 9,
#  "'m": 211,
#  'aragorn': 8,
#  'exuberantly': 4,
#  'shootout': 22,
#  'rockumentary': 9,
#  'dunst': 8,
#  u'marathon': 12,
#  'back-story': 7,
#  'typically': 9,
#  'twinkle': 9,
#  u'quandary': 15,
#  'swinging': 31,
#  'good-natured': 46,
#  'time': 2293,
#  u'push': 67,
#  'someplace': 13,
#  'dogme': 8,
#  'breadth': 31,
#  'natured': 13,
#  'chain': 20,
#  'perch': 12,
#  u'machination': 6,
#  'crocodile': 26,
#  'avalanche': 14,
#  'jarring': 37,
#  'gut-wrenching': 23,
#  'touchingly': 4,
#  'ear-pleasing': 11,
#  'hole': 128,
#  'millisecond': 14,
#  'ballet': 15,
#  'ennui-hobbled': 7,
#  'ver': 14,
#  'rambling': 28,
#  'hardass': 15,
#  'rousing': 17,
#  'obsessively': 7,
#  'methodically': 8,
#  'suspending': 7,
#  'fairlane': 8,
#  'irksome': 16,
#  'poorly-constructed': 10,
#  'even-flowing': 12,
#  'tenacious': 26,
#  'dragonfly': 35,
#  'over-the-top': 68,
#  'recipe': 36,
#  'two-way': 11,
#  'olympus': 10,
#  'choice': 128,
#  'turbulent': 20,
#  'gloomy': 13,
#  'rapturous': 4,
#  'ghostbusters': 4,
#  'exact': 37,
#  u'minute': 861,
#  'room': 181,
#  'wondrously': 19,
#  'judaism': 5,
#  'been-told-a': 11,
#  'variable': 6,
#  'amoral': 16,
#  ...}

# %%
import operator

print "Total number of unique words: " + str(len(vocab_set))
sorted_vocab_freq = list(reversed(sorted(vocab_freq.items(), key=operator.itemgetter(1))))
print "Top 100 most frequently used words: " + str(sorted_vocab_freq[:100])
# Out:
# Total number of unique words: 15179
# Top 100 most frequently used words: [('the', 51220), ('a', 44748), ('of', 32308), ('and', 31763), ('to', 22448), ('it', 18728), ('in', 13754), ('is', 13447), ('that', 12327), ('with', 7750), ('film', 7668), ('for', 7417), (u'movie', 7250), ('an', 6479), ('this', 5677), ('but', 5126), ('be', 4977), ('you', 4827), ('on', 4730), ("n't", 3970), ('by', 3918), ('more', 3906), ('his', 3827), ('one', 3783), ('about', 3682), ('not', 3562), ('at', 3550), ('or', 3472), ('from', 3462), ('than', 3458), ('all', 3201), ('have', 3134), ('like', 3092), ('are', 3059), (u'ha', 2950), ('character', 2850), ('story', 2831), ('so', 2644), ('-rrb-', 2438), ('make', 2415), ('out', 2380), ('who', 2359), ('time', 2293), ('most', 2227), ('into', 2163), ('too', 2143), ('up', 2104), ('-lrb-', 2098), ('good', 2066), ('if', 1979), ('comedy', 1939), ('what', 1899), ('their', 1899), ('...', 1884), ('life', 1862), ('much', 1862), ('no', 1801), ('can', 1769), ('i', 1768), (u'way', 1767), ('your', 1753), ('just', 1714), ('some', 1701), ('work', 1701), (u'doe', 1674), ('even', 1597), ('will', 1588), ('little', 1575), ('funny', 1522), ('performance', 1475), ('any', 1456), ('very', 1451), ('been', 1410), ('only', 1393), ('which', 1360), ('he', 1358), ('love', 1353), ('feel', 1285), ('do', 1280), ('new', 1278), ('there', 1257), ('enough', 1248), ('her', 1240), (u'wa', 1235), (u'u', 1229), (u'get', 1223), ('director', 1218), ('bad', 1211), (u'thing', 1209), ('own', 1207), ('they', 1204), ('audience', 1180), ('other', 1154), ('something', 1152), ('would', 1118), ('look', 1114), ('never', 1114), ('we', 1113), ('through', 1098), ('many', 1094)]

# %% [markdown]
# Words like 'film' and 'story' are commonly used in movie reviews. It is also interesting to note that words like 'comedy' and 'funny' are commonly used. This could suggest that many of the reviews are done on comedic movies. However, there can be other contexts which those words could be placed in, and which could suggest otherwise. An example would be '....a comedy of errors...' which would suggest negative sentiment.

# %%
sentences = []
sentid = 0
sentlabels = []
for index,row in raw_train_data.iterrows():
    if (sentid!=row['SentenceId']):
        sentid = row['SentenceId']
        sentlabels.append(row['Sentiment'])
        sentences.append(row['Tokens'])
sentences
# Out:
# [['a',
#   'series',
#   'of',
#   u'escapade',
#   'demonstrating',
#   'the',
#   'adage',
#   'that',
#   'what',
#   'is',
#   'good',
#   'for',
#   'the',
#   'goose',
#   'is',
#   'also',
#   'good',
#   'for',
#   'the',
#   'gander',
#   'some',
#   'of',
#   'which',
#   'occasionally',
#   'amuses',
#   'but',
#   'none',
#   'of',
#   'which',
#   u'amount',
#   'to',
#   'much',
#   'of',
#   'a',
#   'story'],
#  ['this',
#   'quiet',
#   'introspective',
#   'and',
#   'entertaining',
#   'independent',
#   'is',
#   'worth',
#   'seeking'],
#  ['even',
#   u'fan',
#   'of',
#   'ismail',
#   'merchant',
#   'work',
#   'i',
#   'suspect',
#   'would',
#   'have',
#   'a',
#   'hard',
#   'time',
#   'sitting',
#   'through',
#   'this',
#   'one'],
#  ['a',
#   'positively',
#   'thrilling',
#   'combination',
#   'of',
#   'ethnography',
#   'and',
#   'all',
#   'the',
#   'intrigue',
#   'betrayal',
#   'deceit',
#   'and',
#   'murder',
#   'of',
#   'a',
#   'shakespearean',
#   'tragedy',
#   'or',
#   'a',
#   'juicy',
#   'soap',
#   'opera'],
#  ['aggressive', 'self-glorification', 'and', 'a', 'manipulative', 'whitewash'],
#  ['a',
#   'comedy-drama',
#   'of',
#   'nearly',
#   'epic',
#   u'proportion',
#   'rooted',
#   'in',
#   'a',
#   'sincere',
#   'performance',
#   'by',
#   'the',
#   'title',
#   'character',
#   'undergoing',
#   'midlife',
#   'crisis'],
#  ['narratively', 'trouble', 'every', 'day', 'is', 'a', 'plodding', 'mess'],
#  ['the',
#   'importance',
#   'of',
#   'being',
#   'earnest',
#   'so',
#   'thick',
#   'with',
#   'wit',
#   'it',
#   u'play',
#   'like',
#   'a',
#   'reading',
#   'from',
#   'bartlett',
#   'familiar',
#   u'quotation'],
#  ['but', 'it', u'doe', "n't", 'leave', 'you', 'with', 'much'],
#  ['you', 'could', 'hate', 'it', 'for', 'the', 'same', 'reason'],
#  ['there',
#   'little',
#   'to',
#   'recommend',
#   'snow',
#   u'dog',
#   'unless',
#   'one',
#   'considers',
#   'cliched',
#   'dialogue',
#   'and',
#   'perverse',
#   'escapism',
#   'a',
#   'source',
#   'of',
#   'high',
#   'hilarity'],
#  ['kung',
#   'pow',
#   'is',
#   'oedekerk',
#   'realization',
#   'of',
#   'his',
#   'childhood',
#   'dream',
#   'to',
#   'be',
#   'in',
#   'a',
#   'martial-arts',
#   'flick',
#   'and',
#   u'prof',
#   'that',
#   'sometimes',
#   'the',
#   u'dream',
#   'of',
#   'youth',
#   'should',
#   'remain',
#   'just',
#   'that'],
#  ['the', u'performance', 'are', 'an', 'absolute', 'joy'],
#  ['fresnadillo',
#   u'ha',
#   'something',
#   'serious',
#   'to',
#   'say',
#   'about',
#   'the',
#   u'way',
#   'in',
#   'which',
#   'extravagant',
#   'chance',
#   'can',
#   'distort',
#   'our',
#   'perspective',
#   'and',
#   'throw',
#   u'u',
#   'off',
#   'the',
#   'path',
#   'of',
#   'good',
#   'sense'],
#  ['i',
#   'still',
#   'like',
#   'moonlight',
#   'mile',
#   'better',
#   'judgment',
#   'be',
#   'damned'],
#  ['a',
#   'welcome',
#   'relief',
#   'from',
#   'baseball',
#   u'movie',
#   'that',
#   'try',
#   'too',
#   'hard',
#   'to',
#   'be',
#   'mythic',
#   'this',
#   'one',
#   'is',
#   'a',
#   'sweet',
#   'and',
#   'modest',
#   'and',
#   'ultimately',
#   'winning',
#   'story'],
#  ['a',
#   'bilingual',
#   'charmer',
#   'just',
#   'like',
#   'the',
#   'woman',
#   'who',
#   'inspired',
#   'it'],
#  ['like',
#   'a',
#   u'le',
#   'dizzily',
#   'gorgeous',
#   'companion',
#   'to',
#   'mr.',
#   'wong',
#   'in',
#   'the',
#   'mood',
#   'for',
#   'love',
#   'very',
#   'much',
#   'a',
#   'hong',
#   'kong',
#   'movie',
#   'despite',
#   u'it',
#   'mainland',
#   'setting'],
#  [u'a',
#   'inept',
#   u'a',
#   'big-screen',
#   u'remake',
#   'of',
#   'the',
#   u'avenger',
#   'and',
#   'the',
#   'wild',
#   'wild',
#   'west'],
#  ['it', 'everything', 'you', "'d", 'expect', 'but', 'nothing', 'more'],
#  ['best', 'indie', 'of', 'the', 'year', 'so', 'far'],
#  ['hatfield',
#   'and',
#   u'hick',
#   'make',
#   'the',
#   'oddest',
#   'of',
#   u'couple',
#   'and',
#   'in',
#   'this',
#   'sense',
#   'the',
#   'movie',
#   'becomes',
#   'a',
#   'study',
#   'of',
#   'the',
#   u'gamble',
#   'of',
#   'the',
#   'publishing',
#   'world',
#   'offering',
#   'a',
#   'case',
#   'study',
#   'that',
#   'exists',
#   'apart',
#   'from',
#   'all',
#   'the',
#   'movie',
#   'political',
#   u'ramification'],
#  ['it',
#   'like',
#   'going',
#   'to',
#   'a',
#   'house',
#   'party',
#   'and',
#   'watching',
#   'the',
#   'host',
#   'defend',
#   'himself',
#   'against',
#   'a',
#   'frothing',
#   'ex-girlfriend'],
#  ['that',
#   'the',
#   'chuck',
#   'norris',
#   'grenade',
#   'gag',
#   'occurs',
#   'about',
#   '7',
#   u'time',
#   'during',
#   u'windtalker',
#   'is',
#   'a',
#   'good',
#   'indication',
#   'of',
#   'how',
#   'serious-minded',
#   'the',
#   'film',
#   'is'],
#  ['the',
#   'plot',
#   'is',
#   'romantic',
#   'comedy',
#   'boilerplate',
#   'from',
#   'start',
#   'to',
#   'finish'],
#  ['it',
#   'arrives',
#   'with',
#   'an',
#   'impeccable',
#   'pedigree',
#   'mongrel',
#   'pep',
#   'and',
#   'almost',
#   'indecipherable',
#   'plot',
#   u'complication'],
#  ['a',
#   'film',
#   'that',
#   'clearly',
#   u'mean',
#   'to',
#   'preach',
#   'exclusively',
#   'to',
#   'the',
#   'converted'],
#  ['while',
#   'the',
#   'importance',
#   'of',
#   'being',
#   'earnest',
#   u'offer',
#   u'opportunity',
#   'for',
#   'occasional',
#   u'smile',
#   'and',
#   u'chuckle',
#   'it',
#   u'doe',
#   "n't",
#   'give',
#   u'u',
#   'a',
#   'reason',
#   'to',
#   'be',
#   'in',
#   'the',
#   'theater',
#   'beyond',
#   'wilde',
#   'wit',
#   'and',
#   'the',
#   u'actor',
#   u'performance'],
#  ['the',
#   'latest',
#   'vapid',
#   'actor',
#   'exercise',
#   'to',
#   'appropriate',
#   'the',
#   'structure',
#   'of',
#   'arthur',
#   'schnitzler',
#   'reigen'],
#  ['more',
#   'vaudeville',
#   'show',
#   'than',
#   'well-constructed',
#   'narrative',
#   'but',
#   'on',
#   'those',
#   u'term',
#   'it',
#   'inoffensive',
#   'and',
#   'actually',
#   'rather',
#   'sweet'],
#  ['nothing', 'more', 'than', 'a', 'run-of-the-mill', 'action', 'flick'],
#  ['hampered',
#   'no',
#   'paralyzed',
#   'by',
#   'a',
#   'self-indulgent',
#   'script',
#   '...',
#   'that',
#   u'aim',
#   'for',
#   'poetry',
#   'and',
#   u'end',
#   'up',
#   'sounding',
#   'like',
#   'satire'],
#  ['ice',
#   'age',
#   'is',
#   'the',
#   'first',
#   'computer-generated',
#   'feature',
#   'cartoon',
#   'to',
#   'feel',
#   'like',
#   'other',
#   u'movie',
#   'and',
#   'that',
#   u'make',
#   'for',
#   'some',
#   'glacial',
#   'pacing',
#   'early',
#   'on'],
#  ['there',
#   'very',
#   'little',
#   'sense',
#   'to',
#   'what',
#   'going',
#   'on',
#   'here',
#   'but',
#   'the',
#   u'maker',
#   'serve',
#   'up',
#   'the',
#   u'cliche',
#   'with',
#   'considerable',
#   'dash'],
#  ['cattaneo',
#   'should',
#   'have',
#   'followed',
#   'the',
#   'runaway',
#   'success',
#   'of',
#   'his',
#   'first',
#   'film',
#   'the',
#   'full',
#   'monty',
#   'with',
#   'something',
#   'different'],
#  ['they',
#   "'re",
#   'the',
#   'unnamed',
#   'easily',
#   'substitutable',
#   u'force',
#   'that',
#   'serve',
#   u'a',
#   'whatever',
#   'terror',
#   'the',
#   u'hero',
#   'of',
#   'horror',
#   u'movie',
#   'try',
#   'to',
#   'avoid'],
#  ['it',
#   'almost',
#   u'feel',
#   u'a',
#   'if',
#   'the',
#   'movie',
#   'is',
#   'more',
#   'interested',
#   'in',
#   'entertaining',
#   'itself',
#   'than',
#   'in',
#   'amusing',
#   u'u'],
#  ['the',
#   'movie',
#   'progression',
#   'into',
#   'rambling',
#   'incoherence',
#   u'give',
#   'new',
#   'meaning',
#   'to',
#   'the',
#   'phrase',
#   'fatal',
#   'script',
#   'error'],
#  ['do',
#   "n't",
#   'judge',
#   'this',
#   'one',
#   'too',
#   'soon',
#   '-',
#   'it',
#   'a',
#   'dark',
#   'gritty',
#   'story',
#   'but',
#   'it',
#   u'take',
#   'off',
#   'in',
#   'totally',
#   'unexpected',
#   u'direction',
#   'and',
#   u'keep',
#   'on',
#   'going'],
#  ['so', 'could', 'young', u'romantic', 'out', 'on', 'a', 'date'],
#  ['tartakovsky',
#   'team',
#   u'ha',
#   'some',
#   'freakish',
#   u'power',
#   'of',
#   'visual',
#   'charm',
#   'but',
#   'the',
#   'five',
#   u'writer',
#   'slip',
#   'into',
#   'the',
#   'modern',
#   'rut',
#   'of',
#   'narrative',
#   'banality'],
#  ['vincent',
#   'gallo',
#   'is',
#   'right',
#   'at',
#   'home',
#   'in',
#   'this',
#   'french',
#   'shocker',
#   'playing',
#   'his',
#   'usual',
#   'bad',
#   'boy',
#   'weirdo',
#   'role'],
#  ['if',
#   'a',
#   'horror',
#   'movie',
#   'primary',
#   'goal',
#   'is',
#   'to',
#   'frighten',
#   'and',
#   'disturb',
#   'then',
#   'they',
#   u'work',
#   'spectacularly',
#   'well',
#   '...',
#   'a',
#   'shiver-inducing',
#   'nerve-rattling',
#   'ride'],
#  ['this',
#   '100-minute',
#   'movie',
#   'only',
#   u'ha',
#   'about',
#   '25',
#   u'minute',
#   'of',
#   'decent',
#   'material'],
#  ['fortunately', 'you', 'still', 'have', 'that', 'option'],
#  [u'le',
#   'the',
#   'sensational',
#   'true-crime',
#   'hell-jaunt',
#   u'purist',
#   'might',
#   'like',
#   'and',
#   'more',
#   'experimental',
#   'in',
#   u'it',
#   'storytelling',
#   '-lrb-',
#   'though',
#   'no',
#   u'le',
#   'horrifying',
#   'for',
#   'it',
#   '-rrb-'],
#  [u'a',
#   'tricky',
#   'and',
#   'satisfying',
#   u'a',
#   'any',
#   'of',
#   'david',
#   'mamet',
#   'airless',
#   'cinematic',
#   'shell',
#   u'game'],
#  ['i',
#   "'m",
#   'sure',
#   'the',
#   'filmmaker',
#   'would',
#   'disagree',
#   'but',
#   'honestly',
#   'i',
#   'do',
#   "n't",
#   'see',
#   'the',
#   'point'],
#  ['jones',
#   u'ha',
#   'tackled',
#   'a',
#   'meaty',
#   'subject',
#   'and',
#   'drawn',
#   'engaging',
#   u'character',
#   'while',
#   'peppering',
#   'the',
#   u'page',
#   'with',
#   'memorable',
#   u'zinger'],
#  ['bloody',
#   'sunday',
#   u'ha',
#   'the',
#   'grace',
#   'to',
#   'call',
#   'for',
#   'prevention',
#   'rather',
#   'than',
#   'to',
#   'place',
#   'blame',
#   'making',
#   'it',
#   'one',
#   'of',
#   'the',
#   'best',
#   'war',
#   u'movie',
#   'ever',
#   'made'],
#  [u'take',
#   'a',
#   'clunky',
#   'tv-movie',
#   'approach',
#   'to',
#   'detailing',
#   'a',
#   'chapter',
#   'in',
#   'the',
#   'life',
#   'of',
#   'the',
#   'celebrated',
#   'irish',
#   'playwright',
#   'poet',
#   'and',
#   'drinker'],
#  ['finally',
#   'coming',
#   'down',
#   'off',
#   'of',
#   'miramax',
#   'deep',
#   u'shelf',
#   'after',
#   'a',
#   'couple',
#   'of',
#   'aborted',
#   u'attempt',
#   'waking',
#   'up',
#   'in',
#   'reno',
#   u'make',
#   'a',
#   'strong',
#   'case',
#   'for',
#   'letting',
#   'sleeping',
#   u'dog',
#   'lie'],
#  ['thanks',
#   'largely',
#   'to',
#   'williams',
#   'all',
#   'the',
#   'interesting',
#   u'development',
#   'are',
#   'processed',
#   'in',
#   '60',
#   u'minute',
#   'the',
#   'rest',
#   'is',
#   'just',
#   'an',
#   'overexposed',
#   'waste',
#   'of',
#   'film'],
#  [u'come',
#   'across',
#   u'a',
#   'a',
#   'relic',
#   'from',
#   'a',
#   'bygone',
#   'era',
#   'and',
#   u'it',
#   u'convolution',
#   '...',
#   'feel',
#   'silly',
#   'rather',
#   'than',
#   'plausible'],
#  ['perhaps',
#   'it',
#   'cliche',
#   'to',
#   'call',
#   'the',
#   'film',
#   'refreshing',
#   'but',
#   'it',
#   'is'],
#  ['both', 'lead', u'performance', 'are', 'oscar-size'],
#  ['run', 'for', 'your', u'life', '!'],
#  ['mark',
#   'pellington',
#   'latest',
#   'pop',
#   'thriller',
#   'is',
#   u'a',
#   'kooky',
#   'and',
#   'overeager',
#   u'a',
#   'it',
#   'is',
#   'spooky',
#   'and',
#   'subtly',
#   'in',
#   'love',
#   'with',
#   'myth'],
#  ['claude',
#   'chabrol',
#   'camera',
#   u'ha',
#   'a',
#   'way',
#   'of',
#   'gently',
#   'swaying',
#   'back',
#   'and',
#   'forth',
#   u'a',
#   'it',
#   u'cradle',
#   u'it',
#   u'character',
#   'veiling',
#   'tension',
#   'beneath',
#   'otherwise',
#   'tender',
#   u'movement'],
#  ['transforms',
#   'one',
#   'of',
#   '-lrb-',
#   'shakespeare',
#   '-rrb-',
#   'deepest',
#   u'tragedy',
#   'into',
#   'a',
#   'smart',
#   'new',
#   'comedy'],
#  ['the',
#   'screenplay',
#   'by',
#   'james',
#   'eric',
#   'james',
#   'horton',
#   'and',
#   'director',
#   'peter',
#   "o'fallon",
#   '...',
#   'is',
#   'so',
#   'pat',
#   'it',
#   u'make',
#   'your',
#   'teeth',
#   'hurt'],
#  ['but',
#   'arriving',
#   'at',
#   'a',
#   'particularly',
#   'dark',
#   'moment',
#   'in',
#   'history',
#   'it',
#   u'offer',
#   'flickering',
#   u'reminder',
#   'of',
#   'the',
#   u'tie',
#   'that',
#   'bind',
#   u'u'],
#  [u'it',
#   'generic',
#   u'villain',
#   'lack',
#   'any',
#   'intrigue',
#   '-lrb-',
#   'other',
#   'than',
#   'their',
#   'funny',
#   u'accent',
#   '-rrb-',
#   'and',
#   'the',
#   'action',
#   u'scene',
#   'are',
#   'poorly',
#   'delivered'],
#  ['the',
#   u'character',
#   'are',
#   'more',
#   'deeply',
#   'thought',
#   'through',
#   'than',
#   'in',
#   'most',
#   'right-thinking',
#   u'film'],
#  ['the',
#   'film',
#   'despite',
#   'the',
#   'gratuitous',
#   'cinematic',
#   u'distraction',
#   'impressed',
#   'upon',
#   'it',
#   'is',
#   'still',
#   'good',
#   'fun'],
#  ['downright',
#   'transparent',
#   'is',
#   'the',
#   'script',
#   'endless',
#   'assault',
#   'of',
#   'embarrassingly',
#   'ham-fisted',
#   'sex',
#   u'joke',
#   'that',
#   'reek',
#   'of',
#   'a',
#   'script',
#   'rewrite',
#   'designed',
#   'to',
#   'garner',
#   'the',
#   'film',
#   'a',
#   'cooler',
#   'pg-13',
#   'rating'],
#  ['a',
#   'smart',
#   'provocative',
#   'drama',
#   'that',
#   u'doe',
#   'the',
#   'nearly',
#   'impossible',
#   'it',
#   u'get',
#   'under',
#   'the',
#   'skin',
#   'of',
#   'a',
#   'man',
#   'we',
#   'only',
#   'know',
#   u'a',
#   'an',
#   'evil',
#   'monstrous',
#   'lunatic'],
#  ['it', 'like', 'a', 'drive-by'],
#  ['is',
#   'many',
#   u'thing',
#   'stoner',
#   'midnight',
#   'flick',
#   'sci-fi',
#   'deconstruction',
#   'gay',
#   'fantasia',
#   'but',
#   'above',
#   'all',
#   'it',
#   'a',
#   'love',
#   'story',
#   u'a',
#   'sanguine',
#   u'a',
#   u'it',
#   'title'],
#  ['a',
#   'very',
#   'funny',
#   'romantic',
#   'comedy',
#   'about',
#   'two',
#   'skittish',
#   'new',
#   'york',
#   'middle-agers',
#   'who',
#   'stumble',
#   'into',
#   'a',
#   'relationship',
#   'and',
#   'then',
#   'struggle',
#   'furiously',
#   'with',
#   'their',
#   u'fear',
#   'and',
#   u'foible'],
#  ['but',
#   'it',
#   u'ha',
#   'an',
#   'ambition',
#   'to',
#   'say',
#   'something',
#   'about',
#   u'it',
#   u'subject',
#   'but',
#   'not',
#   'a',
#   'willingness'],
#  ['-lrb-',
#   'scherfig',
#   '-rrb-',
#   u'ha',
#   'made',
#   'a',
#   'movie',
#   'that',
#   'will',
#   'leave',
#   'you',
#   'wondering',
#   'about',
#   'the',
#   u'character',
#   u'life',
#   'after',
#   'the',
#   'clever',
#   u'credit',
#   'roll'],
#  ['-lrb-', 'an', '-rrb-', 'absorbing', 'documentary'],
#  [u'reek',
#   'of',
#   'rot',
#   'and',
#   'hack',
#   'work',
#   'from',
#   'start',
#   'to',
#   'finish'],
#  [u'play',
#   'like',
#   'a',
#   'series',
#   'of',
#   u'vignette',
#   u'clip',
#   'of',
#   'a',
#   'film',
#   'that',
#   'are',
#   'still',
#   'looking',
#   'for',
#   'a',
#   'common',
#   'through-line'],
#  [],
#  ['the',
#   'major',
#   'problem',
#   'with',
#   u'windtalker',
#   'is',
#   'that',
#   'the',
#   'bulk',
#   'of',
#   'the',
#   'movie',
#   u'center',
#   'on',
#   'the',
#   'wrong',
#   'character'],
#  ['swimfan',
#   'like',
#   'fatal',
#   'attraction',
#   'eventually',
#   u'go',
#   'overboard',
#   'with',
#   'a',
#   'loony',
#   'melodramatic',
#   'denouement',
#   'in',
#   'which',
#   'a',
#   'high',
#   'school',
#   'swimming',
#   'pool',
#   u'substitute',
#   'for',
#   'a',
#   'bathtub'],
#  ['this',
#   'is',
#   'a',
#   'heartfelt',
#   'story',
#   '...',
#   'it',
#   'just',
#   'is',
#   "n't",
#   'a',
#   'very',
#   'involving',
#   'one'],
#  ['an',
#   'unsettling',
#   'memorable',
#   'cinematic',
#   'experience',
#   'that',
#   u'doe',
#   u'it',
#   u'predecessor',
#   'proud'],
#  ['all',
#   'in',
#   'all',
#   'it',
#   'a',
#   'pretty',
#   'good',
#   'execution',
#   'of',
#   'a',
#   'story',
#   'that',
#   'a',
#   'lot',
#   'richer',
#   'than',
#   'the',
#   u'one',
#   'hollywood',
#   'action',
#   u'screenwriter',
#   'usually',
#   'come',
#   'up',
#   'with',
#   'on',
#   'their',
#   'own'],
#  ['phillip',
#   'noyce',
#   'and',
#   'all',
#   'of',
#   'his',
#   u'actor',
#   u'a',
#   'well',
#   u'a',
#   'his',
#   'cinematographer',
#   'christopher',
#   'doyle',
#   'understand',
#   'the',
#   'delicate',
#   'forcefulness',
#   'of',
#   'greene',
#   'prose',
#   'and',
#   'it',
#   'there',
#   'on',
#   'the',
#   'screen',
#   'in',
#   'their',
#   'version',
#   'of',
#   'the',
#   'quiet',
#   'american'],
#  ['the',
#   'pianist',
#   u'lack',
#   'the',
#   'quick',
#   'emotional',
#   u'connection',
#   'of',
#   'steven',
#   'spielberg',
#   'schindler',
#   'list'],
#  ['inventive',
#   'fun',
#   'intoxicatingly',
#   'sexy',
#   'violent',
#   'self-indulgent',
#   'and',
#   'maddening'],
#  [u'tell', 'a', 'fascinating', 'compelling', 'story'],
#  ['written',
#   'flatly',
#   'by',
#   'david',
#   'kendall',
#   'and',
#   'directed',
#   'barely',
#   'by',
#   'there',
#   'something',
#   'about',
#   'mary',
#   'co-writer',
#   'ed',
#   'decter'],
#  ['highly',
#   'recommended',
#   'viewing',
#   'for',
#   u'it',
#   'courage',
#   u'idea',
#   'technical',
#   'proficiency',
#   'and',
#   'great',
#   'acting'],
#  ['in',
#   'imax',
#   'in',
#   'short',
#   'it',
#   'just',
#   u'a',
#   'wonderful',
#   'on',
#   'the',
#   'big',
#   'screen'],
#  ['it',
#   u'show',
#   u'u',
#   'a',
#   'slice',
#   'of',
#   'life',
#   'that',
#   'very',
#   'different',
#   'from',
#   'our',
#   'own',
#   'and',
#   'yet',
#   'instantly',
#   'recognizable'],
#  ['amid',
#   'the',
#   'shock',
#   'and',
#   'curiosity',
#   u'factor',
#   'the',
#   'film',
#   'is',
#   'just',
#   'a',
#   'corny',
#   'examination',
#   'of',
#   'a',
#   'young',
#   'actress',
#   'trying',
#   'to',
#   'find',
#   'her',
#   'way'],
#  ['it',
#   'lazy',
#   'for',
#   'a',
#   'movie',
#   'to',
#   'avoid',
#   'solving',
#   'one',
#   'problem',
#   'by',
#   'trying',
#   'to',
#   'distract',
#   u'u',
#   'with',
#   'the',
#   'solution',
#   'to',
#   'another'],
#  ['...',
#   'it',
#   u'a',
#   'comprehensible',
#   u'a',
#   'any',
#   u'dummy',
#   'guide',
#   'something',
#   'even',
#   'non-techies',
#   'can',
#   'enjoy'],
#  ['entertains',
#   'not',
#   'so',
#   'much',
#   'because',
#   'of',
#   u'it',
#   'music',
#   'or',
#   'comic',
#   u'antic',
#   'but',
#   'through',
#   'the',
#   'perverse',
#   'pleasure',
#   'of',
#   'watching',
#   'disney',
#   'scrape',
#   'the',
#   'bottom',
#   'of',
#   u'it',
#   'own',
#   'cracker',
#   'barrel'],
#  ['writer\\/director',
#   'burr',
#   u'steer',
#   'emphasizes',
#   'the',
#   'q',
#   'in',
#   'quirky',
#   'with',
#   'mixed',
#   u'result'],
#  ['scarcely',
#   'worth',
#   'a',
#   'mention',
#   'apart',
#   'from',
#   'reporting',
#   'on',
#   'the',
#   'number',
#   'of',
#   u'tumbleweed',
#   'blowing',
#   'through',
#   'the',
#   'empty',
#   u'theatre',
#   'graced',
#   'with',
#   u'it',
#   'company'],
#  ['invigorating',
#   'surreal',
#   'and',
#   'resonant',
#   'with',
#   'a',
#   'rainbow',
#   'of',
#   'emotion'],
#  ['analyze',
#   'that',
#   'is',
#   'one',
#   'of',
#   'those',
#   'crass',
#   'contrived',
#   u'sequel',
#   'that',
#   'not',
#   'only',
#   'fails',
#   'on',
#   u'it',
#   'own',
#   'but',
#   u'make',
#   'you',
#   'second-guess',
#   'your',
#   'affection',
#   'for',
#   'the',
#   'original'],
#  ['report',
#   'card',
#   u'doe',
#   "n't",
#   'live',
#   'up',
#   'to',
#   'the',
#   'exalted',
#   'tagline',
#   '-',
#   'there',
#   'definite',
#   'room',
#   'for',
#   'improvement'],
#  ['it',
#   'not',
#   'a',
#   'particularly',
#   'good',
#   'film',
#   'but',
#   'neither',
#   'is',
#   'it',
#   'a',
#   'monsterous',
#   'one'],
#  ['tsai',
#   'may',
#   'be',
#   'ploughing',
#   'the',
#   'same',
#   'furrow',
#   'once',
#   'too',
#   'often'],
#  ['-lrb-',
#   'green',
#   'is',
#   '-rrb-',
#   'the',
#   'comedy',
#   'equivalent',
#   'of',
#   'saddam',
#   'hussein',
#   'and',
#   'i',
#   "'m",
#   'just',
#   'about',
#   'ready',
#   'to',
#   'go',
#   'to',
#   'the',
#   'u.n.',
#   'and',
#   'ask',
#   'permission',
#   'for',
#   'a',
#   'preemptive',
#   'strike'],
#  ['a',
#   'surprisingly',
#   'solid',
#   'achievement',
#   'by',
#   'director',
#   'malcolm',
#   'd.',
#   'lee',
#   'and',
#   'writer',
#   'john',
#   'ridley'],
#  ['massoud',
#   'story',
#   'is',
#   'an',
#   'epic',
#   'but',
#   'also',
#   'a',
#   'tragedy',
#   'the',
#   'record',
#   'of',
#   'a',
#   'tenacious',
#   'humane',
#   'fighter',
#   'who',
#   u'wa',
#   'also',
#   'the',
#   'prisoner',
#   '-lrb-',
#   'and',
#   'ultimately',
#   'the',
#   'victim',
#   '-rrb-',
#   'of',
#   'history'],
#  ['changing', u'lane', u'try', 'for', 'more'],
#  ['shyamalan', 'should', 'stop', 'trying', 'to', 'please', 'his', 'mom'],
#  ['a',
#   'macabre',
#   'and',
#   'very',
#   'stylized',
#   'swedish',
#   'fillm',
#   'about',
#   'a',
#   'modern',
#   'city',
#   'where',
#   'all',
#   'the',
#   'religious',
#   'and',
#   'civic',
#   u'virtue',
#   'that',
#   'hold',
#   'society',
#   'in',
#   'place',
#   'are',
#   'in',
#   u'tatter'],
#  ['one',
#   'of',
#   'recent',
#   'memory',
#   'most',
#   'thoughtful',
#   u'film',
#   'about',
#   'art',
#   u'ethic',
#   'and',
#   'the',
#   'cost',
#   'of',
#   'moral',
#   'compromise'],
#  ['the',
#   'narrative',
#   'is',
#   'so',
#   'consistently',
#   'unimaginative',
#   'that',
#   'probably',
#   'the',
#   'only',
#   'way',
#   'to',
#   'have',
#   'saved',
#   'the',
#   'film',
#   'is',
#   'with',
#   'the',
#   'aid',
#   'of',
#   'those',
#   'wisecracking',
#   'mystery',
#   'science',
#   'theater',
#   '3000',
#   u'guy'],
#  ['filmmaker',
#   'tian',
#   'zhuangzhuang',
#   'triumphantly',
#   u'return',
#   'to',
#   'narrative',
#   'filmmaking',
#   'with',
#   'a',
#   'visually',
#   'masterful',
#   'work',
#   'of',
#   'quiet',
#   'power'],
#  ['a',
#   'mawkish',
#   'self-parody',
#   'that',
#   u'play',
#   'like',
#   'some',
#   'weird',
#   'masterpiece',
#   'theater',
#   'sketch',
#   'with',
#   'neither',
#   'a',
#   'point',
#   'of',
#   'view',
#   'nor',
#   'a',
#   'compelling',
#   'reason',
#   'for',
#   'being'],
#  [u'take',
#   'one',
#   'character',
#   'we',
#   'do',
#   "n't",
#   'like',
#   'and',
#   'another',
#   'we',
#   'do',
#   "n't",
#   'believe',
#   'and',
#   u'put',
#   'them',
#   'into',
#   'a',
#   'battle',
#   'of',
#   u'will',
#   'that',
#   'is',
#   'impossible',
#   'to',
#   'care',
#   'about',
#   'and',
#   'is',
#   "n't",
#   'very',
#   'funny'],
#  ['and',
#   'if',
#   'you',
#   'appreciate',
#   'the',
#   'one-sided',
#   'theme',
#   'to',
#   'lawrence',
#   'over-indulgent',
#   'tirade',
#   'then',
#   'knock',
#   'yourself',
#   'out',
#   'and',
#   'enjoy',
#   'the',
#   'big',
#   'screen',
#   'postcard',
#   'that',
#   'is',
#   'a',
#   'self-glorified',
#   'martin',
#   'lawrence',
#   'lovefest'],
#  ['the',
#   'whole',
#   'film',
#   u'ha',
#   'this',
#   'sneaky',
#   'feel',
#   'to',
#   'it',
#   u'a',
#   'if',
#   'the',
#   'director',
#   'is',
#   'trying',
#   'to',
#   'dupe',
#   'the',
#   'viewer',
#   'into',
#   'taking',
#   'it',
#   'all',
#   u'a',
#   'very',
#   'important',
#   'simply',
#   'because',
#   'the',
#   'movie',
#   'is',
#   'ugly',
#   'to',
#   'look',
#   'at',
#   'and',
#   'not',
#   'a',
#   'hollywood',
#   'product'],
#  ['whenever',
#   'it',
#   'threatens',
#   'to',
#   'get',
#   'bogged',
#   'down',
#   'in',
#   'earnest',
#   'dramaturgy',
#   'a',
#   'stirring',
#   'visual',
#   'sequence',
#   'like',
#   'a',
#   'surge',
#   'through',
#   'swirling',
#   u'rapid',
#   'or',
#   'a',
#   'leap',
#   'from',
#   'pinnacle',
#   'to',
#   'pinnacle',
#   u'rous',
#   u'u'],
#  ['swinging',
#   'the',
#   'film',
#   u'make',
#   'it',
#   'seem',
#   'is',
#   'not',
#   'a',
#   'hobby',
#   'that',
#   'attracts',
#   'the',
#   'young',
#   'and',
#   'fit'],
#  ['but', 'when', 'it', u'doe', 'you', "'re", 'entirely', 'unprepared'],
#  ['devos',
#   'delivers',
#   'a',
#   'perfect',
#   'performance',
#   'that',
#   u'capture',
#   'the',
#   'innocence',
#   'and',
#   'budding',
#   u'demon',
#   'within',
#   'a',
#   'wallflower'],
#  ['300',
#   u'year',
#   'of',
#   'russian',
#   'history',
#   'and',
#   'culture',
#   'compressed',
#   'into',
#   'an',
#   'evanescent',
#   'seamless',
#   'and',
#   'sumptuous',
#   'stream',
#   'of',
#   'consciousness'],
#  ['the',
#   u'filmmaker',
#   'want',
#   'nothing',
#   'else',
#   'than',
#   'to',
#   'show',
#   u'u',
#   'a',
#   'good',
#   'time',
#   'and',
#   'in',
#   'their',
#   'cheap',
#   'b',
#   'movie',
#   'way',
#   'they',
#   'succeed'],
#  ['mr.',
#   'polanski',
#   'is',
#   'in',
#   'his',
#   'element',
#   'here',
#   'alone',
#   'abandoned',
#   'but',
#   'still',
#   'consoled',
#   'by',
#   'his',
#   'art',
#   'which',
#   'is',
#   'more',
#   'than',
#   'he',
#   u'ha',
#   'ever',
#   'revealed',
#   'before',
#   'about',
#   'the',
#   'source',
#   'of',
#   'his',
#   'spiritual',
#   'survival'],
#  ['spider-man',
#   'is',
#   'better',
#   'than',
#   'any',
#   'summer',
#   'blockbuster',
#   'we',
#   'had',
#   'to',
#   'endure',
#   'last',
#   'summer',
#   'and',
#   'hopefully',
#   u'set',
#   'the',
#   'tone',
#   'for',
#   'a',
#   'summer',
#   'of',
#   'good',
#   'stuff'],
#  ['absorbing', 'character'],
#  ['violent', 'vulgar', 'and', 'forgettably', 'entertaining'],
#  ['it',
#   'the',
#   'unsettling',
#   u'image',
#   'of',
#   'a',
#   'war-ravaged',
#   'land',
#   'that',
#   'prove',
#   'more',
#   'potent',
#   'and',
#   'riveting',
#   'than',
#   'the',
#   'unlikely',
#   'story',
#   'of',
#   'sarah',
#   'and',
#   'harrison'],
#  [u'wind',
#   'up',
#   'being',
#   'both',
#   'revelatory',
#   'and',
#   'narcissistic',
#   'achieving',
#   'some',
#   'honest',
#   'insight',
#   'into',
#   u'relationship',
#   'that',
#   'most',
#   'high-concept',
#   u'film',
#   'candy-coat',
#   'with',
#   'pat',
#   u'storyline',
#   'precious',
#   u'circumstance',
#   'and',
#   'beautiful',
#   u'star'],
#  ['if',
#   'mostly',
#   'martha',
#   'is',
#   'mostly',
#   'unsurprising',
#   'it',
#   'still',
#   'a',
#   'sweet',
#   'even',
#   'delectable',
#   'diversion'],
#  ['a',
#   'thoughtful',
#   'and',
#   'surprisingly',
#   'affecting',
#   'portrait',
#   'of',
#   'a',
#   'screwed-up',
#   'man',
#   'who',
#   'dared',
#   'to',
#   'mess',
#   'with',
#   'some',
#   'powerful',
#   'people',
#   'seen',
#   'through',
#   'the',
#   u'eye',
#   'of',
#   'the',
#   'idealistic',
#   'kid',
#   'who',
#   'chooses',
#   'to',
#   'champion',
#   'his',
#   'ultimately',
#   'losing',
#   'cause'],
#  ['keenly',
#   'observed',
#   'and',
#   'refreshingly',
#   'natural',
#   'swimming',
#   u'get',
#   'the',
#   u'detail',
#   'right',
#   'from',
#   u'it',
#   'promenade',
#   'of',
#   'barely',
#   'clad',
#   u'body',
#   'in',
#   'myrtle',
#   'beach',
#   's.c.',
#   'to',
#   'the',
#   'adrenaline',
#   'jolt',
#   'of',
#   'a',
#   'sudden',
#   'lunch',
#   'rush',
#   'at',
#   'the',
#   'diner'],
#  ['a',
#   'brilliant',
#   'gag',
#   'at',
#   'the',
#   'expense',
#   'of',
#   'those',
#   'who',
#   'paid',
#   'for',
#   'it',
#   'and',
#   'those',
#   'who',
#   'pay',
#   'to',
#   'see',
#   'it'],
#  ['a',
#   'triumph',
#   'a',
#   'film',
#   'that',
#   'hews',
#   'out',
#   'a',
#   'world',
#   'and',
#   u'carry',
#   u'u',
#   'effortlessly',
#   'from',
#   'darkness',
#   'to',
#   'light'],
#  ['just',
#   'about',
#   'everyone',
#   'involved',
#   'here',
#   'seems',
#   'to',
#   'be',
#   'coasting'],
#  ['a',
#   'fascinating',
#   'dark',
#   'thriller',
#   'that',
#   u'keep',
#   'you',
#   'hooked',
#   'on',
#   'the',
#   'delicious',
#   'pulpiness',
#   'of',
#   u'it',
#   'lurid',
#   'fiction'],
#  ['i',
#   'suspect',
#   'this',
#   'is',
#   'the',
#   'kind',
#   'of',
#   'production',
#   'that',
#   'would',
#   'have',
#   'been',
#   'funnier',
#   'if',
#   'the',
#   'director',
#   'had',
#   'released',
#   'the',
#   u'outtake',
#   'theatrically',
#   'and',
#   'used',
#   'the',
#   'film',
#   u'a',
#   'a',
#   'bonus',
#   'feature',
#   'on',
#   'the',
#   'dvd'],
#  ['it',
#   'hard',
#   'to',
#   'say',
#   'who',
#   'might',
#   'enjoy',
#   'this',
#   'are',
#   'there',
#   'tolstoy',
#   u'groupie',
#   'out',
#   'there',
#   '?'],
#  ['daughter',
#   'from',
#   'danang',
#   'reveals',
#   'that',
#   u'effort',
#   'toward',
#   'closure',
#   'only',
#   'open',
#   'new',
#   u'wound'],
#  ['one',
#   'of',
#   'the',
#   'year',
#   'most',
#   'weirdly',
#   'engaging',
#   'and',
#   'unpredictable',
#   'character',
#   u'piece'],
#  ['intriguing', 'and', 'downright', 'intoxicating'],
#  ['although',
#   'fairly',
#   'involving',
#   u'a',
#   'far',
#   u'a',
#   'it',
#   u'go',
#   'the',
#   'film',
#   u'doe',
#   "n't",
#   'end',
#   'up',
#   'having',
#   'much',
#   'that',
#   'is',
#   'fresh',
#   'to',
#   'say',
#   'about',
#   'growing',
#   'up',
#   'catholic',
#   'or',
#   'really',
#   'anything'],
#  ['the',
#   'movie',
#   'is',
#   'silly',
#   'beyond',
#   'comprehension',
#   'and',
#   'even',
#   'if',
#   'it',
#   'were',
#   "n't",
#   'silly',
#   'it',
#   'would',
#   'still',
#   'be',
#   'beyond',
#   'comprehension'],
#  ['sleek', 'and', 'arty'],
#  ['poor',
#   'editing',
#   'bad',
#   'bluescreen',
#   'and',
#   'ultra-cheesy',
#   'dialogue',
#   'highlight',
#   'the',
#   'radical',
#   'action'],
#  ['-lrb-',
#   'cho',
#   'face',
#   'is',
#   '-rrb-',
#   'an',
#   'amazing',
#   'slapstick',
#   'instrument',
#   'creating',
#   'a',
#   'scrapbook',
#   'of',
#   'living',
#   'mug',
#   u'shot'],
#  ['it',
#   u'get',
#   'the',
#   u'detail',
#   'of',
#   u'it',
#   'time',
#   'frame',
#   'right',
#   'but',
#   'it',
#   'completely',
#   u'miss',
#   u'it',
#   u'emotion'],
#  ['initial',
#   'strangeness',
#   'inexorably',
#   u'give',
#   'way',
#   'to',
#   'rote',
#   'sentimentality',
#   'and',
#   'mystical',
#   'tenderness',
#   'becomes',
#   'narrative',
#   'expedience'],
#  ['it',
#   u'let',
#   'you',
#   'brush',
#   'up',
#   'against',
#   'the',
#   'humanity',
#   'of',
#   'a',
#   'psycho',
#   'without',
#   'making',
#   'him',
#   'any',
#   u'le',
#   'psycho'],
#  ['like',
#   'the',
#   'world',
#   'of',
#   'his',
#   'film',
#   'hartley',
#   'created',
#   'a',
#   'monster',
#   'but',
#   'did',
#   "n't",
#   'know',
#   'how',
#   'to',
#   'handle',
#   'it'],
#  ['when',
#   'cowering',
#   'and',
#   'begging',
#   'at',
#   'the',
#   u'foot',
#   'a',
#   'scruffy',
#   'giannini',
#   'madonna',
#   u'give',
#   'her',
#   'best',
#   'performance',
#   'since',
#   'abel',
#   'ferrara',
#   'had',
#   'her',
#   'beaten',
#   'to',
#   'a',
#   'pulp',
#   'in',
#   'his',
#   'dangerous',
#   'game'],
#  ['too',
#   'clumsy',
#   'in',
#   'key',
#   u'moment',
#   '...',
#   'to',
#   'make',
#   'a',
#   'big',
#   'splash'],
#  ['because',
#   'eight',
#   'legged',
#   u'freak',
#   'is',
#   'partly',
#   'an',
#   'homage',
#   'to',
#   'them',
#   'tarantula',
#   'and',
#   'other',
#   'low',
#   '-',
#   'budget',
#   'b-movie',
#   u'thriller',
#   'of',
#   'the',
#   '1950s',
#   'and',
#   "'60s",
#   'the',
#   'movie',
#   'is',
#   'a',
#   'silly',
#   '-lrb-',
#   'but',
#   'not',
#   'sophomoric',
#   '-rrb-',
#   'romp',
#   'through',
#   'horror',
#   'and',
#   'hellish',
#   u'condition'],
#  ['it',
#   u'feel',
#   'like',
#   'very',
#   'light',
#   'errol',
#   'morris',
#   'focusing',
#   'on',
#   'eccentricity',
#   'but',
#   'failing',
#   'ultimately',
#   'to',
#   'make',
#   'something',
#   'bigger',
#   'out',
#   'of',
#   u'it',
#   'scrapbook',
#   'of',
#   u'oddball'],
#  ['spielberg',
#   'realization',
#   'of',
#   'a',
#   'near-future',
#   'america',
#   'is',
#   'masterful'],
#  ['there',
#   'a',
#   'scientific',
#   'law',
#   'to',
#   'be',
#   'discerned',
#   'here',
#   'that',
#   u'producer',
#   'would',
#   'be',
#   'well',
#   'to',
#   'heed',
#   'mediocre',
#   u'movie',
#   'start',
#   'to',
#   'drag',
#   u'a',
#   'soon',
#   u'a',
#   'the',
#   'action',
#   u'speed',
#   'up',
#   ';',
#   'when',
#   'the',
#   u'explosion',
#   'start',
#   'they',
#   'fall',
#   'to',
#   u'piece'],
#  ['he',
#   'one',
#   'of',
#   'the',
#   'few',
#   'cool',
#   u'actor',
#   'who',
#   'never',
#   'seems',
#   'aware',
#   'of',
#   'his',
#   'own',
#   'coolness'],
#  [u'feel',
#   'like',
#   'the',
#   'work',
#   'of',
#   'an',
#   'artist',
#   'who',
#   'is',
#   'simply',
#   'tired',
#   'of',
#   'fighting',
#   'the',
#   'same',
#   u'fight',
#   'of',
#   'putting',
#   'the',
#   'weight',
#   'of',
#   'the',
#   'world',
#   'on',
#   'his',
#   u'shoulder',
#   'of',
#   'playing',
#   'with',
#   'narrative',
#   'form'],
#  ['...', 'stale', 'and', 'uninspired'],
#  ['in',
#   'the',
#   'director',
#   'cut',
#   'the',
#   'film',
#   'is',
#   'not',
#   'only',
#   'a',
#   'love',
#   'song',
#   'to',
#   'the',
#   u'movie',
#   'but',
#   'it',
#   'also',
#   'is',
#   'more',
#   'fully',
#   'an',
#   'example',
#   'of',
#   'the',
#   'kind',
#   'of',
#   'lush',
#   'all-enveloping',
#   'movie',
#   'experience',
#   'it',
#   'rhapsodizes'],
#  [u'ha',
#   'the',
#   'rare',
#   'capability',
#   'to',
#   'soothe',
#   'and',
#   'break',
#   'your',
#   'heart',
#   'with',
#   'a',
#   'single',
#   'stroke'],
#  ['eerily', 'accurate', 'depiction', 'of', 'depression'],
#  [u'a',
#   'a',
#   'feature-length',
#   'film',
#   'it',
#   u'wear',
#   'out',
#   u'it',
#   'welcome',
#   u'a',
#   'tryingly',
#   u'a',
#   'the',
#   'title',
#   'character'],
#  ['an',
#   'uncluttered',
#   'resonant',
#   'gem',
#   'that',
#   u'relay',
#   u'it',
#   'universal',
#   u'point',
#   'without',
#   u'lecture',
#   'or',
#   u'confrontation'],
#  ['the',
#   'story',
#   'alone',
#   'could',
#   'force',
#   'you',
#   'to',
#   'scratch',
#   'a',
#   'hole',
#   'in',
#   'your',
#   'head'],
#  ['it',
#   'the',
#   u'filmmaker',
#   'post-camp',
#   'comprehension',
#   'of',
#   'what',
#   'made',
#   'old-time',
#   'b',
#   u'movie',
#   'good-bad',
#   'that',
#   u'make',
#   'eight',
#   'legged',
#   u'freak',
#   'a',
#   'perfectly',
#   'entertaining',
#   'summer',
#   'diversion'],
#  [u'a',
#   'any',
#   'creature-feature',
#   'fan',
#   u'know',
#   'when',
#   'you',
#   'cross',
#   'toxic',
#   u'chemical',
#   'with',
#   'a',
#   'bunch',
#   'of',
#   'exotic',
#   u'creature',
#   'you',
#   'get',
#   'a',
#   'lot',
#   'of',
#   'running',
#   'around',
#   'screaming',
#   'and',
#   'death'],
#  ['you',
#   'bet',
#   'there',
#   'is',
#   'and',
#   'it',
#   'what',
#   u'make',
#   'this',
#   'rather',
#   'convoluted',
#   'journey',
#   'worth',
#   'taking'],
#  ['before',
#   'it',
#   u'take',
#   'a',
#   'sudden',
#   'turn',
#   'and',
#   'devolves',
#   'into',
#   'a',
#   'bizarre',
#   'sort',
#   'of',
#   'romantic',
#   'comedy',
#   'steven',
#   'shainberg',
#   'adaptation',
#   'of',
#   'mary',
#   'gaitskill',
#   'harrowing',
#   'short',
#   'story',
#   '...',
#   'is',
#   'a',
#   'brilliantly',
#   'played',
#   'deeply',
#   'unsettling',
#   'experience'],
#  ['kim',
#   'ki-deok',
#   'seems',
#   'to',
#   'have',
#   'in',
#   'mind',
#   'an',
#   '-lrb-',
#   'emotionally',
#   'at',
#   'least',
#   '-rrb-',
#   'adolescent',
#   'audience',
#   'demanding',
#   'regular',
#   u'shock',
#   'and',
#   u'bout',
#   'of',
#   'barely',
#   'defensible',
#   'sexual',
#   'violence',
#   'to',
#   'keep',
#   'it',
#   'interested'],
#  [u'ha',
#   'no',
#   'reason',
#   'to',
#   'exist',
#   'other',
#   'than',
#   'to',
#   'employ',
#   'hollywood',
#   u'kid',
#   'and',
#   'people',
#   'who',
#   'owe',
#   u'favor',
#   'to',
#   'their',
#   'famous',
#   u'parent'],
#  ['a',
#   'well-made',
#   'but',
#   'emotionally',
#   'scattered',
#   'film',
#   'whose',
#   'hero',
#   u'give',
#   'his',
#   'heart',
#   'only',
#   'to',
#   'the',
#   'dog'],
#  ['those',
#   'who',
#   'love',
#   'cinema',
#   'paradiso',
#   'will',
#   'find',
#   'the',
#   'new',
#   u'scene',
#   'interesting',
#   'but',
#   'few',
#   'will',
#   'find',
#   'the',
#   'movie',
#   'improved'],
#  ['campanella',
#   u'get',
#   'the',
#   'tone',
#   'just',
#   'right',
#   'funny',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'sad',
#   'in',
#   'the',
#   'middle',
#   'of',
#   'hopeful'],
#  ['nothing',
#   'more',
#   'than',
#   'an',
#   'amiable',
#   'but',
#   'unfocused',
#   'bagatelle',
#   'that',
#   u'play',
#   'like',
#   'a',
#   'loosely-connected',
#   'string',
#   'of',
#   'acting-workshop',
#   u'exercise'],
#  ['it', 'a', 'sharp', 'movie', 'about', 'otherwise', 'dull', u'subject'],
#  ['wallace',
#   u'get',
#   'a',
#   'bit',
#   'heavy',
#   'handed',
#   'with',
#   'his',
#   'message',
#   'at',
#   u'time',
#   'and',
#   u'ha',
#   'a',
#   'visual',
#   'flair',
#   'that',
#   u'wax',
#   'poetic',
#   'far',
#   'too',
#   'much',
#   'for',
#   'our',
#   'taste'],
#  ['charming',
#   'and',
#   'funny',
#   '-lrb-',
#   'but',
#   'ultimately',
#   'silly',
#   '-rrb-',
#   'movie'],
#  ['...',
#   'the',
#   'one',
#   'thing',
#   'this',
#   'wild',
#   'film',
#   u'ha',
#   'that',
#   'other',
#   'imax',
#   u'film',
#   'do',
#   "n't",
#   u'chimp',
#   u'lot',
#   'of',
#   u'chimp',
#   'all',
#   'blown',
#   'up',
#   'to',
#   'the',
#   'size',
#   'of',
#   'a',
#   'house'],
#  [u'start',
#   'out',
#   'mediocre',
#   u'spiral',
#   'downward',
#   'and',
#   u'thud',
#   'to',
#   'the',
#   'bottom',
#   'of',
#   'the',
#   'pool',
#   'with',
#   'an',
#   'utterly',
#   'incompetent',
#   'conclusion'],
#  ['this', 'is', 'a', u'child', 'film', 'in', 'the', 'truest', 'sense'],
#  ['horrendously',
#   'amateurish',
#   'filmmaking',
#   'that',
#   'is',
#   'plainly',
#   'dull',
#   'and',
#   'visually',
#   'ugly',
#   'when',
#   'it',
#   'is',
#   "n't",
#   'incomprehensible'],
#  ['beautifully',
#   'crafted',
#   'engaging',
#   'filmmaking',
#   'that',
#   'should',
#   'attract',
#   'upscale',
#   u'audience',
#   'hungry',
#   'for',
#   'quality',
#   'and',
#   'a',
#   'nostalgic',
#   'twisty',
#   'yarn',
#   'that',
#   'will',
#   'keep',
#   'them',
#   'guessing'],
#  ['an', 'awkwardly', 'contrived', 'exercise', 'in', 'magic', 'realism'],
#  ['the',
#   'punch',
#   u'line',
#   'that',
#   'miss',
#   'unfortunately',
#   'outnumber',
#   'the',
#   u'hit',
#   'by',
#   'three-to-one'],
#  ['like',
#   'smoke',
#   u'signal',
#   'the',
#   'film',
#   'is',
#   'also',
#   'imbued',
#   'with',
#   'strong',
#   u'theme',
#   'of',
#   'familial',
#   u'tie',
#   'and',
#   'spirituality',
#   'that',
#   'are',
#   'powerful',
#   'and',
#   'moving',
#   'without',
#   'stooping',
#   'to',
#   'base',
#   'melodrama'],
#  ['evokes',
#   'the',
#   'style',
#   'and',
#   'flash',
#   'of',
#   'the',
#   'double-cross',
#   'that',
#   'made',
#   'mamet',
#   'house',
#   'of',
#   u'game',
#   'and',
#   'last',
#   'fall',
#   'heist',
#   'so',
#   'much',
#   'fun'],
#  ['the',
#   'film',
#   u'aim',
#   'to',
#   'be',
#   'funny',
#   'uplifting',
#   'and',
#   'moving',
#   'sometimes',
#   'all',
#   'at',
#   'once'],
#  ['at',
#   'a',
#   'brief',
#   '42',
#   u'minute',
#   'we',
#   'need',
#   'more',
#   'x',
#   'and',
#   u'le',
#   'blab'],
#  ['the',
#   'spalding',
#   'gray',
#   'equivalent',
#   'of',
#   'a',
#   'teen',
#   'gross-out',
#   'comedy'],
#  ['there',
#   'a',
#   'great',
#   'deal',
#   'of',
#   'corny',
#   'dialogue',
#   'and',
#   'preposterous',
#   u'moment'],
#  ['uneven', 'but', 'a', 'lot', 'of', 'fun'],
#  ['the', 'result', 'might', 'look', 'like', 'vulgar'],
#  ['the',
#   'film',
#   u'rehash',
#   'several',
#   'old',
#   u'theme',
#   'and',
#   'is',
#   'capped',
#   'with',
#   'pointless',
#   u'extreme',
#   'it',
#   'insanely',
#   'violent',
#   'and',
#   'very',
#   'graphic'],
#  ['the',
#   u'dragon',
#   'are',
#   'the',
#   'real',
#   u'star',
#   'of',
#   'reign',
#   'of',
#   'fire',
#   'and',
#   'you',
#   'wo',
#   "n't",
#   'be',
#   'disappointed'],
#  ['it',
#   'never',
#   u'play',
#   u'a',
#   'dramatic',
#   'even',
#   'when',
#   'dramatic',
#   u'thing',
#   'happen',
#   'to',
#   'people'],
#  ['manages',
#   'to',
#   'please',
#   u'it',
#   'intended',
#   'audience',
#   u'child',
#   'without',
#   'placing',
#   'their',
#   u'parent',
#   'in',
#   'a',
#   'coma-like',
#   'state'],
#  ['the',
#   'movie',
#   'generates',
#   'plot',
#   u'point',
#   'with',
#   'a',
#   'degree',
#   'of',
#   'randomness',
#   'usually',
#   'achieved',
#   'only',
#   'by',
#   'lottery',
#   'drawing'],
#  ['though',
#   'the',
#   'film',
#   'never',
#   'veers',
#   'from',
#   u'it',
#   'comic',
#   'course',
#   u'it',
#   'unintentional',
#   u'parallel',
#   'might',
#   'inadvertently',
#   'evoke',
#   u'memory',
#   'and',
#   u'emotion',
#   'which',
#   'are',
#   'anything',
#   'but',
#   'humorous'],
#  ['the', 'film', 'can', 'depress', 'you', 'about', 'life', 'itself'],
#  ['if',
#   'you',
#   'saw',
#   'it',
#   'on',
#   'tv',
#   'you',
#   "'d",
#   'probably',
#   'turn',
#   'it',
#   'off',
#   'convinced',
#   'that',
#   'you',
#   'had',
#   'already',
#   'seen',
#   'that',
#   'movie'],
#  ['you',
#   'get',
#   'the',
#   'impression',
#   'that',
#   'writer',
#   'and',
#   'director',
#   'burr',
#   u'steer',
#   u'know',
#   'the',
#   'territory',
#   '...',
#   'but',
#   'his',
#   'sense',
#   'of',
#   'humor',
#   u'ha',
#   'yet',
#   'to',
#   'lose',
#   'the',
#   'smug',
#   'self-satisfaction',
#   'usually',
#   'associated',
#   'with',
#   'the',
#   'better',
#   'private',
#   u'school'],
#  ['this', 'is', 'a', 'superior', 'horror', 'flick'],
#  ['the',
#   'movie',
#   'heavy-handed',
#   'screenplay',
#   'navigates',
#   'a',
#   'fast',
#   'fade',
#   'into',
#   'pomposity',
#   'and',
#   'pretentiousness'],
#  ['a', 'little', 'weak', 'and', 'it', 'is', "n't", 'that', 'funny'],
#  ['but',
#   'they',
#   'do',
#   "n't",
#   'fit',
#   'well',
#   'together',
#   'and',
#   'neither',
#   'is',
#   'well',
#   'told'],
#  ['being',
#   'latently',
#   'gay',
#   'and',
#   'liking',
#   'to',
#   'read',
#   'are',
#   'hardly',
#   'enough'],
#  ['more',
#   'sophisticated',
#   'and',
#   'literate',
#   'than',
#   'such',
#   u'picture',
#   'usually',
#   'are',
#   '...',
#   'an',
#   'amusing',
#   'little',
#   'catch'],
#  ['storytelling', u'feel', 'slight'],
#  ['monte',
#   'cristo',
#   'smartly',
#   'emphasizes',
#   'the',
#   'well-wrought',
#   'story',
#   'and',
#   'omits',
#   u'needle',
#   'chase',
#   u'scene',
#   'and',
#   'swordfights',
#   u'a',
#   'the',
#   'revenge',
#   'unfolds'],
#  ['it',
#   'a',
#   'fairy',
#   'tale',
#   'that',
#   u'come',
#   'from',
#   'a',
#   'renowned',
#   'indian',
#   'film',
#   'culture',
#   'that',
#   'allows',
#   u'american',
#   'to',
#   'finally',
#   'revel',
#   'in',
#   u'it',
#   'splendor'],
#  ['well-done',
#   'supernatural',
#   'thriller',
#   'with',
#   'keen',
#   u'insight',
#   'into',
#   'parapsychological',
#   u'phenomenon',
#   'and',
#   'the',
#   'soulful',
#   u'nuance',
#   'of',
#   'the',
#   'grieving',
#   'process'],
#  ['...',
#   'only',
#   'bond',
#   'can',
#   'save',
#   u'u',
#   'from',
#   'the',
#   'latest',
#   'eccentric',
#   'super-wealthy',
#   'megalomaniac',
#   'bent',
#   'on',
#   'world',
#   'domination',
#   'and',
#   'destruction'],
#  ['it',
#   'is',
#   'depressing',
#   'ruthlessly',
#   'pained',
#   'and',
#   'depraved',
#   'the',
#   'movie',
#   'equivalent',
#   'of',
#   'staring',
#   'into',
#   'an',
#   'open',
#   'wound'],
#  ['damon',
#   'brings',
#   'the',
#   'proper',
#   'conviction',
#   'to',
#   'his',
#   'role',
#   u'a',
#   '-lrb-',
#   'jason',
#   'bourne',
#   '-rrb-'],
#  [u'parent', 'beware', ';', 'this', 'is', 'downright', 'movie', 'penance'],
#  ['when', 'it', 'this', 'rich', 'and', 'luscious', 'who', u'care', '?'],
#  ['a', 'singularly', 'off-putting', 'romantic', 'comedy'],
#  ['director',
#   'boris',
#   'von',
#   'sychowski',
#   'instead',
#   'opts',
#   'for',
#   'a',
#   'routine',
#   'slasher',
#   'film',
#   'that',
#   u'wa',
#   'probably',
#   'more',
#   'fun',
#   'to',
#   'make',
#   'than',
#   'it',
#   'is',
#   'to',
#   'sit',
#   'through'],
#  ['would',
#   "'ve",
#   'been',
#   'nice',
#   'if',
#   'the',
#   u'screenwriter',
#   'had',
#   'trusted',
#   u'audience',
#   'to',
#   'understand',
#   'a',
#   'complex',
#   'story',
#   'and',
#   'left',
#   'off',
#   'the',
#   'film',
#   'predictable',
#   'denouement'],
#  ['a',
#   'superfluous',
#   'sequel',
#   '...',
#   'plagued',
#   'by',
#   'that',
#   'old',
#   'familiar',
#   'feeling',
#   'of',
#   'let',
#   'get',
#   'this',
#   'thing',
#   'over',
#   'with',
#   'everyone',
#   u'ha',
#   'shown',
#   'up',
#   'at',
#   'the',
#   'appointed',
#   'time',
#   'and',
#   'place',
#   'but',
#   'visible',
#   'enthusiasm',
#   'is',
#   'mighty',
#   'hard',
#   'to',
#   'find'],
#  ['an',
#   'earnest',
#   'roughshod',
#   'document',
#   'it',
#   u'serf',
#   u'a',
#   'a',
#   'workable',
#   'primer',
#   'for',
#   'the',
#   'region',
#   'recent',
#   'history',
#   'and',
#   'would',
#   'make',
#   'a',
#   'terrific',
#   '10th-grade',
#   'learning',
#   'tool'],
#  [u'cloak',
#   'a',
#   'familiar',
#   'anti-feminist',
#   'equation',
#   '-lrb-',
#   'career',
#   '-',
#   u'kid',
#   '=',
#   'misery',
#   '-rrb-',
#   'in',
#   'tiresome',
#   'romantic-comedy',
#   u'dud'],
#  ['a',
#   'film',
#   'that',
#   u'play',
#   u'thing',
#   'so',
#   'nice',
#   "'n",
#   'safe',
#   u'a',
#   'to',
#   'often',
#   'play',
#   'like',
#   'a',
#   'milquetoast',
#   'movie',
#   'of',
#   'the',
#   'week',
#   'blown',
#   'up',
#   'for',
#   'the',
#   'big',
#   'screen'],
#  ['his',
#   'work',
#   'transcends',
#   'the',
#   'boy-meets-girl',
#   'posturing',
#   'of',
#   'typical',
#   'love',
#   u'story'],
#  ['an',
#   'even',
#   'more',
#   'predictable',
#   'cliche-ridden',
#   'endeavor',
#   'than',
#   u'it',
#   'predecessor'],
#  [u'play',
#   'like',
#   'a',
#   'bad',
#   'blend',
#   'of',
#   'an',
#   'overripe',
#   'episode',
#   'of',
#   'tv',
#   'dawson',
#   'creek',
#   'and',
#   'a',
#   'recycled',
#   'and',
#   'dumbed-down',
#   'version',
#   'of',
#   'love',
#   'story'],
#  ['the',
#   'script',
#   u'cover',
#   'huge',
#   'heavy',
#   u'topic',
#   'in',
#   'a',
#   'bland',
#   'surfacey',
#   'way',
#   'that',
#   u'doe',
#   "n't",
#   'offer',
#   'any',
#   'insight',
#   'into',
#   'why',
#   'for',
#   'instance',
#   'good',
#   u'thing',
#   'happen',
#   'to',
#   'bad',
#   'people'],
#  ['the',
#   'film',
#   'is',
#   'so',
#   'bad',
#   'it',
#   u'doe',
#   "n't",
#   'improve',
#   'upon',
#   'the',
#   'experience',
#   'of',
#   'staring',
#   'at',
#   'a',
#   'blank',
#   'screen'],
#  ['they',
#   'threw',
#   u'load',
#   'of',
#   'money',
#   'at',
#   'an',
#   'idea',
#   'that',
#   'should',
#   "'ve",
#   'been',
#   'so',
#   'much',
#   'more',
#   'even',
#   'if',
#   'it',
#   u'wa',
#   'only',
#   'made',
#   'for',
#   'teenage',
#   u'boy',
#   'and',
#   'wrestling',
#   u'fan'],
#  ['it',
#   'difficult',
#   'to',
#   'imagine',
#   'that',
#   'a',
#   'more',
#   'confused',
#   u'le',
#   'interesting',
#   'and',
#   'more',
#   'sloppily',
#   'made',
#   'film',
#   'could',
#   'possibly',
#   'come',
#   'down',
#   'the',
#   'road',
#   'in',
#   '2002'],
#  ['though',
#   'the',
#   'film',
#   'is',
#   'well-intentioned',
#   'one',
#   'could',
#   'rent',
#   'the',
#   'original',
#   'and',
#   'get',
#   'the',
#   'same',
#   'love',
#   'story',
#   'and',
#   'parable'],
#  ['jolting',
#   'into',
#   'charleston',
#   u'rhythm',
#   'the',
#   'story',
#   u'ha',
#   'the',
#   'sizzle',
#   'of',
#   'old',
#   'news',
#   'that',
#   u'ha',
#   'finally',
#   'found',
#   'the',
#   'right',
#   'vent',
#   '-lrb-',
#   'accurate',
#   '?'],
#  ['or', 'both'],
#  ['williams',
#   u'play',
#   'sy',
#   'another',
#   'of',
#   'his',
#   'open-faced',
#   'smiling',
#   u'madman',
#   'like',
#   'the',
#   'killer',
#   'in',
#   'insomnia'],
#  ['phoned-in', 'business', u'a', 'usual'],
#  ['with',
#   u'it',
#   'lackadaisical',
#   'plotting',
#   'and',
#   'mindless',
#   'action',
#   'all',
#   'about',
#   'the',
#   u'benjamin',
#   'evokes',
#   'the',
#   'bottom',
#   'tier',
#   'of',
#   'blaxploitation',
#   u'flick',
#   'from',
#   'the',
#   '1970s'],
#  ['ah',
#   'yes',
#   'that',
#   'would',
#   'be',
#   'me',
#   'fighting',
#   'off',
#   'the',
#   'urge',
#   'to',
#   'doze'],
#  ['thoughtless',
#   'random',
#   'superficial',
#   'humour',
#   'and',
#   'a',
#   'lot',
#   'of',
#   'very',
#   'bad',
#   'scouse',
#   u'accent'],
#  ['in',
#   'an',
#   'era',
#   'where',
#   'big',
#   u'star',
#   'and',
#   'high',
#   'production',
#   u'value',
#   'are',
#   'standard',
#   'procedure',
#   'narc',
#   u'strike',
#   'a',
#   'defiantly',
#   'retro',
#   'chord',
#   'and',
#   'outpaces',
#   u'it',
#   u'contemporary',
#   'with',
#   'daring',
#   'and',
#   'verve'],
#  ['a',
#   'rip-roaring',
#   'comedy',
#   'action',
#   'fest',
#   'that',
#   "'ll",
#   'put',
#   u'hair',
#   'on',
#   'your',
#   'chest'],
#  ['...',
#   'a',
#   'thoughtful',
#   'what-if',
#   'for',
#   'the',
#   'heart',
#   u'a',
#   'well',
#   u'a',
#   'the',
#   'mind'],
#  ['miyazaki',
#   'is',
#   'one',
#   'of',
#   'world',
#   'cinema',
#   'most',
#   'wondrously',
#   'gifted',
#   u'artist',
#   'and',
#   u'storyteller'],
#  ['a',
#   'chronicle',
#   'not',
#   'only',
#   'of',
#   'one',
#   'man',
#   'quest',
#   'to',
#   'be',
#   'president',
#   'but',
#   'of',
#   'how',
#   'that',
#   'man',
#   'single-handedly',
#   'turned',
#   'a',
#   'plane',
#   'full',
#   'of',
#   'hard-bitten',
#   'cynical',
#   u'journalist',
#   'into',
#   'what',
#   u'wa',
#   'essentially',
#   'by',
#   'campaign',
#   'end',
#   'an',
#   'extended',
#   'publicity',
#   'department'],
#  ['provides',
#   'the',
#   'kind',
#   'of',
#   'laugh',
#   'therapy',
#   'i',
#   'need',
#   'from',
#   'movie',
#   u'comedy',
#   'offbeat',
#   'humor',
#   'amusing',
#   u'character',
#   'and',
#   'a',
#   'happy',
#   'ending'],
#  [u'feel', 'strangely', 'hollow', 'at', u'it', 'emotional', 'core'],
#  ['at',
#   'a',
#   'time',
#   'when',
#   'commercialism',
#   u'ha',
#   'squeezed',
#   'the',
#   'life',
#   'out',
#   'of',
#   'whatever',
#   'idealism',
#   'american',
#   'moviemaking',
#   'ever',
#   'had',
#   'godfrey',
#   'reggio',
#   'career',
#   u'shine',
#   'like',
#   'a',
#   'lonely',
#   'beacon'],
#  ['director',
#   'roger',
#   'michell',
#   u'doe',
#   'so',
#   'many',
#   'of',
#   'the',
#   'little',
#   u'thing',
#   'right',
#   'that',
#   'it',
#   'difficult',
#   'not',
#   'to',
#   'cuss',
#   'him',
#   'out',
#   'severely',
#   'for',
#   'bungling',
#   'the',
#   'big',
#   'stuff'],
#  ['robert',
#   'harmon',
#   'less-is-more',
#   'approach',
#   'delivers',
#   'real',
#   'bump-in',
#   '-',
#   'the-night',
#   u'chill',
#   'his',
#   'greatest',
#   'triumph',
#   'is',
#   'keeping',
#   'the',
#   'creepy',
#   'crawlies',
#   'hidden',
#   'in',
#   'the',
#   'film',
#   'thick',
#   u'shadow'],
#  ['this',
#   'movie',
#   'may',
#   'not',
#   'have',
#   'the',
#   'highest',
#   'production',
#   u'value',
#   'you',
#   "'ve",
#   'ever',
#   'seen',
#   'but',
#   'it',
#   'the',
#   'work',
#   'of',
#   'an',
#   'artist',
#   'one',
#   'whose',
#   'view',
#   'of',
#   'america',
#   'history',
#   'and',
#   'the',
#   'awkwardness',
#   'of',
#   'human',
#   'life',
#   'is',
#   'generous',
#   'and',
#   'deep'],
#  ['feral', 'and', 'uncomfortable'],
#  ['sillier',
#   'cuter',
#   'and',
#   'shorter',
#   'than',
#   'the',
#   'first',
#   '-lrb-',
#   u'a',
#   'best',
#   'i',
#   'remember',
#   '-rrb-',
#   'but',
#   'still',
#   'a',
#   'very',
#   'good',
#   'time',
#   'at',
#   'the',
#   'cinema'],
#  ['it',
#   'more',
#   'enjoyable',
#   'than',
#   'i',
#   'expected',
#   'though',
#   'and',
#   'that',
#   'because',
#   'the',
#   u'laugh',
#   'come',
#   'from',
#   'fairly',
#   'basic',
#   'comedic',
#   u'construct'],
#  ['black-and-white', 'and', 'unrealistic'],
#  ['the',
#   'film',
#   'is',
#   'predictable',
#   'in',
#   'the',
#   'reassuring',
#   'manner',
#   'of',
#   'a',
#   'beautifully',
#   'sung',
#   'holiday',
#   'carol'],
#  ['the',
#   'only',
#   'camouflage',
#   'carvey',
#   'should',
#   'now',
#   'be',
#   'considering',
#   'is',
#   'a',
#   'paper',
#   'bag',
#   'to',
#   'wear',
#   'over',
#   'his',
#   'head',
#   'when',
#   'he',
#   u'go',
#   'out',
#   'into',
#   'public',
#   'to',
#   'avoid',
#   'being',
#   'recognized',
#   u'a',
#   'the',
#   'man',
#   'who',
#   'bilked',
#   'unsuspecting',
#   u'moviegoer'],
#  ['not',
#   'about',
#   u'scare',
#   'but',
#   'a',
#   'mood',
#   'in',
#   'which',
#   'an',
#   'ominous',
#   'pervasive',
#   'and',
#   'unknown',
#   'threat',
#   'lurks',
#   'just',
#   'below',
#   'the',
#   u'proceeding',
#   'and',
#   u'add',
#   'an',
#   'almost',
#   'constant',
#   'mindset',
#   'of',
#   'suspense'],
#  ['some',
#   'of',
#   'the',
#   'computer',
#   'animation',
#   'is',
#   'handsome',
#   'and',
#   'various',
#   'amusing',
#   u'sidekick',
#   'add',
#   'much-needed',
#   'levity',
#   'to',
#   'the',
#   'otherwise',
#   'bleak',
#   'tale',
#   'but',
#   'overall',
#   'the',
#   'film',
#   'never',
#   u'rise',
#   'above',
#   'mediocrity'],
#  [u'offer',
#   'the',
#   'flash',
#   'of',
#   'rock',
#   u'video',
#   'fused',
#   'with',
#   'solid',
#   u'performance',
#   'and',
#   'eerie',
#   'atmosphere'],
#  ['a',
#   'breezy',
#   'blend',
#   'of',
#   'art',
#   'history',
#   'esoteric',
#   u'musing',
#   'and',
#   'philosophy'],
#  ['now',
#   u'a',
#   'a',
#   'former',
#   'gong',
#   'show',
#   'addict',
#   'i',
#   "'ll",
#   'admit',
#   'it',
#   'my',
#   'only',
#   'complaint',
#   'is',
#   'that',
# ...
#   'before',
#   'cell',
#   u'phone',
#   u'gun',
#   'and',
#   'the',
#   'internal',
#   'combustion',
#   'engine',
#   'but',
#   'the',
#   'politics',
#   'that',
#   'thump',
#   'through',
#   'it',
#   'are',
#   u'a',
#   'timely',
#   u'a',
#   'tomorrow'],
#  ['opening',
#   'with',
#   'some',
#   'contrived',
#   'banter',
#   u'cliche',
#   'and',
#   'some',
#   'loose',
#   u'end',
#   'the',
#   'screenplay',
#   'only',
#   u'come',
#   'into',
#   u'it',
#   'own',
#   'in',
#   'the',
#   'second',
#   'half'],
#  ['a', 'captivating', 'new', 'film'],
#  ['if',
#   'you',
#   'adored',
#   'the',
#   'full',
#   'monty',
#   'so',
#   'resoundingly',
#   'that',
#   'you',
#   "'re",
#   'dying',
#   'to',
#   'see',
#   'the',
#   'same',
#   'old',
#   'thing',
#   'in',
#   'a',
#   'tired',
#   'old',
#   'setting',
#   'then',
#   'this',
#   'should',
#   'keep',
#   'you',
#   'reasonably',
#   'entertained'],
#  ['worth',
#   'catching',
#   'for',
#   u'griffith',
#   'warm',
#   'and',
#   'winning',
#   'central',
#   'performance'],
#  ['sorvino',
#   u'make',
#   'the',
#   'princess',
#   'seem',
#   'smug',
#   'and',
#   'cartoonish',
#   'and',
#   'the',
#   'film',
#   'only',
#   'really',
#   u'come',
#   'alive',
#   'when',
#   'poor',
#   'hermocrates',
#   'and',
#   'leontine',
#   'pathetically',
#   'compare',
#   u'note',
#   'about',
#   'their',
#   'budding',
#   u'amour'],
#  ['while',
#   'this',
#   u'ha',
#   'the',
#   'making',
#   'of',
#   'melodrama',
#   'the',
#   'filmmaker',
#   u'cut',
#   'against',
#   'this',
#   'natural',
#   'grain',
#   'producing',
#   'a',
#   'work',
#   'that',
#   'more',
#   'interested',
#   'in',
#   'asking',
#   u'question',
#   'than',
#   'in',
#   'answering',
#   'them'],
#  ['davis',
#   'is',
#   'funny',
#   'charming',
#   'and',
#   'quirky',
#   'in',
#   'her',
#   'feature',
#   'film',
#   'acting',
#   'debut',
#   u'a',
#   'amy'],
#  ['an',
#   'uncomfortable',
#   'movie',
#   'suffocating',
#   'and',
#   'sometimes',
#   'almost',
#   'senseless',
#   'the',
#   'grey',
#   'zone',
#   u'doe',
#   'have',
#   'a',
#   'center',
#   'though',
#   'a',
#   'morbid',
#   'one'],
#  ['the',
#   'lousy',
#   'john',
#   'q',
#   'all',
#   'but',
#   u'spit',
#   'out',
#   'denzel',
#   'washington',
#   'fine',
#   'performance',
#   'in',
#   'the',
#   'title',
#   'role'],
#  ['so',
#   'devoid',
#   'of',
#   'pleasure',
#   'or',
#   'sensuality',
#   'that',
#   'it',
#   'can',
#   'not',
#   'even',
#   'be',
#   'dubbed',
#   'hedonistic'],
#  ['satin',
#   'rouge',
#   'is',
#   'not',
#   'a',
#   'new',
#   'or',
#   'inventive',
#   'journey',
#   'but',
#   'it',
#   'encouraging',
#   'to',
#   'see',
#   'a',
#   'three-dimensional',
#   'average',
#   'middle-aged',
#   'woman',
#   'experience',
#   'of',
#   'self-discovery',
#   'handled',
#   'with',
#   'such',
#   'sensitivity'],
#  ['a',
#   'pointed',
#   'often',
#   'tender',
#   'examination',
#   'of',
#   'the',
#   u'pro',
#   'and',
#   u'con',
#   'of',
#   'unconditional',
#   'love',
#   'and',
#   'familial',
#   u'duty'],
#  ['another',
#   'trumpet',
#   'blast',
#   'that',
#   'there',
#   'may',
#   'be',
#   'a',
#   'new',
#   'mexican',
#   'cinema',
#   'a-bornin'],
#  ['gorgeous',
#   'to',
#   'look',
#   'at',
#   'but',
#   'insufferably',
#   'tedious',
#   'and',
#   'turgid',
#   '...',
#   'a',
#   'curiously',
#   'constricted',
#   'epic'],
#  ['only',
#   'about',
#   u'a',
#   'sexy',
#   'and',
#   'dangerous',
#   u'a',
#   'an',
#   'actress',
#   'in',
#   'a',
#   'role',
#   'that',
#   'reminds',
#   'at',
#   'every',
#   'turn',
#   'of',
#   'elizabeth',
#   'berkley',
#   'flopping',
#   'dolphin-gasm'],
#  ['their',
#   'contrast',
#   'is',
#   'neither',
#   'dramatic',
#   'nor',
#   'comic',
#   'it',
#   'just',
#   'a',
#   'weird',
#   'fizzle'],
#  ['collateral',
#   'damage',
#   'is',
#   'trash',
#   'but',
#   'it',
#   'earns',
#   'extra',
#   u'point',
#   'by',
#   'acting',
#   u'a',
#   'if',
#   'it',
#   'were',
#   "n't"],
#  ['when',
#   'you',
#   'think',
#   'you',
#   "'ve",
#   'figured',
#   'out',
#   'bielinsky',
#   'great',
#   'game',
#   'that',
#   'when',
#   'you',
#   "'re",
#   'in',
#   'the',
#   'most',
#   'trouble',
#   'he',
#   'the',
#   'con',
#   'and',
#   'you',
#   "'re",
#   'just',
#   'the',
#   'mark'],
#  ['swimming',
#   'is',
#   'above',
#   'all',
#   'about',
#   'a',
#   'young',
#   'woman',
#   'face',
#   'and',
#   'by',
#   'casting',
#   'an',
#   'actress',
#   'whose',
#   'face',
#   u'project',
#   'that',
#   'woman',
#   u'doubt',
#   'and',
#   u'yearning',
#   'it',
#   'succeeds'],
#  ['it',
#   'packed',
#   'to',
#   'bursting',
#   'with',
#   'incident',
#   'and',
#   'with',
#   u'score',
#   'of',
#   u'character',
#   'some',
#   'fictional',
#   'some',
#   'from',
#   'history'],
#  ['you', 'want', 'to', 'call', 'domino'],
#  ['the',
#   'umpteenth',
#   'summer',
#   'skinny',
#   'dip',
#   'in',
#   'jerry',
#   'bruckheimer',
#   'putrid',
#   'pond',
#   'of',
#   'retread',
#   'action',
#   'twaddle'],
#  ['the',
#   'road',
#   'paved',
#   'with',
#   'good',
#   u'intention',
#   u'lead',
#   'to',
#   'the',
#   'video',
#   'store'],
#  ['chris',
#   'columbus',
#   'sequel',
#   'is',
#   'faster',
#   'livelier',
#   'and',
#   'a',
#   'good',
#   'deal',
#   'funnier',
#   'than',
#   'his',
#   'original'],
#  ['full',
#   'of',
#   'flatulence',
#   u'joke',
#   'and',
#   'mild',
#   'sexual',
#   u'reference',
#   'kung',
#   'pow',
#   '!'],
#  ['the', 'whole', 'affair', 'is', u'a', 'predictable', u'a', 'can', 'be'],
#  ['the',
#   'film',
#   'is',
#   'a',
#   'very',
#   'good',
#   'viewing',
#   'alternative',
#   'for',
#   'young',
#   u'woman'],
#  ['to',
#   'those',
#   'who',
#   'have',
#   'not',
#   'read',
#   'the',
#   'book',
#   'the',
#   'film',
#   'is',
#   'a',
#   'much',
#   'better',
#   'mother-daughter',
#   'tale',
#   'than',
#   'last',
#   'summer',
#   'divine',
#   u'secret',
#   'of',
#   'the',
#   'ya-ya',
#   'sisterhood',
#   'but',
#   'that',
#   'not',
#   'saying',
#   'much'],
#  ['but',
#   'it',
#   'also',
#   u'ha',
#   'many',
#   'of',
#   'the',
#   u'thing',
#   'that',
#   'made',
#   'the',
#   'first',
#   'one',
#   'charming'],
#  ['sheridan'],
#  ['this',
#   'slight',
#   'premise',
#   '...',
#   u'work',
#   'because',
#   'of',
#   'the',
#   'ideal',
#   'casting',
#   'of',
#   'the',
#   'masterful',
#   'british',
#   'actor',
#   'ian',
#   'holm',
#   u'a',
#   'the',
#   'aged',
#   'napoleon'],
#  ['but',
#   'never',
#   'mind',
#   'all',
#   'that',
#   ';',
#   'the',
#   u'boob',
#   'are',
#   'fantasti'],
#  ['about',
#   'schmidt',
#   'is',
#   'nicholson',
#   'goofy',
#   'heartfelt',
#   'mesmerizing',
#   'king',
#   'lear'],
#  ['it',
#   'is',
#   'most',
#   'of',
#   'the',
#   u'thing',
#   'costner',
#   u'movie',
#   'are',
#   'known',
#   'for',
#   ';',
#   'it',
#   'sanctimonious',
#   'self-righteous',
#   'and',
#   'so',
#   'eager',
#   'to',
#   'earn',
#   'our',
#   'love',
#   'that',
#   'you',
#   'want',
#   'to',
#   'slap',
#   'it'],
#  ['this', 'is', 'a', 'very', 'funny', 'heartwarming', 'film'],
#  ['it',
#   'a',
#   'piece',
#   'of',
#   'handiwork',
#   'that',
#   u'show',
#   u'it',
#   'indie',
#   u'tatter',
#   'and',
#   'self-conscious',
#   u'seam',
#   'in',
#   u'place',
#   'but',
#   u'ha',
#   'some',
#   'quietly',
#   'moving',
#   u'moment',
#   'and',
#   'an',
#   'intelligent',
#   'subtlety'],
#  ['i',
#   u'wa',
#   'amused',
#   'and',
#   'entertained',
#   'by',
#   'the',
#   'unfolding',
#   'of',
#   'bielinsky',
#   'cleverly',
#   'constructed',
#   'scenario',
#   'and',
#   'greatly',
#   'impressed',
#   'by',
#   'the',
#   'skill',
#   'of',
#   'the',
#   u'actor',
#   'involved',
#   'in',
#   'the',
#   'enterprise'],
#  ['for',
#   'most',
#   'of',
#   'the',
#   'distance',
#   'the',
#   'picture',
#   'provides',
#   'a',
#   'satisfyingly',
#   'unsettling',
#   'ride',
#   'into',
#   'the',
#   'dark',
#   u'place',
#   'of',
#   'our',
#   'national',
#   'psyche'],
#  ['with',
#   'very',
#   'little',
#   'to',
#   'add',
#   'beyond',
#   'the',
#   'dark',
#   u'vision',
#   'already',
#   'relayed',
#   'by',
#   'superb',
#   'recent',
#   u'predecessor',
#   'like',
#   'swimming',
#   'with',
#   u'shark',
#   'and',
#   'the',
#   'player',
#   'this',
#   'latest',
#   'skewering',
#   '...',
#   'may',
#   'put',
#   'off',
#   u'insider',
#   'and',
#   u'outsider',
#   'alike'],
#  ['being',
#   'unique',
#   u'doe',
#   "n't",
#   'necessarily',
#   'equate',
#   'to',
#   'being',
#   'good',
#   'no',
#   'matter',
#   'how',
#   'admirably',
#   'the',
#   u'filmmaker',
#   'have',
#   'gone',
#   'for',
#   'broke'],
#  ['the',
#   'respective',
#   u'charm',
#   'of',
#   'sandra',
#   'bullock',
#   'and',
#   'hugh',
#   'grant',
#   'have',
#   'worn',
#   'threadbare'],
#  ['like',
#   'the',
#   u'hank',
#   'character',
#   'he',
#   'a',
#   'slow',
#   'study',
#   'the',
#   'action',
#   'is',
#   'stilted',
#   'and',
#   'the',
#   'tabloid',
#   'energy',
#   'embalmed'],
#  ['...',
#   'enthusiastically',
#   'invokes',
#   'the',
#   'percussion',
#   'rhythm',
#   'the',
#   'brass',
#   'soul',
#   'and',
#   'the',
#   'sense',
#   'of',
#   'fierce',
#   'competition',
#   'that',
#   u'help',
#   'make',
#   'great',
#   'marching',
#   u'band',
#   'half',
#   'the',
#   'fun',
#   'of',
#   'college',
#   'football',
#   u'game'],
#  ['what',
#   'invigorating',
#   'about',
#   'it',
#   'is',
#   'that',
#   'it',
#   u'doe',
#   "n't",
#   'give',
#   'a',
#   'damn'],
#  ['cacoyannis',
#   'is',
#   'perhaps',
#   'too',
#   'effective',
#   'in',
#   'creating',
#   'an',
#   'atmosphere',
#   'of',
#   'dust-caked',
#   'stagnation',
#   'and',
#   'labored',
#   'gentility'],
#  ['an', 'entertaining', 'if', 'ultimately', 'minor', 'thriller'],
#  ['the',
#   'real',
#   'star',
#   'of',
#   'this',
#   'movie',
#   'is',
#   'the',
#   'score',
#   u'a',
#   'in',
#   'the',
#   u'song',
#   'translate',
#   'well',
#   'to',
#   'film',
#   'and',
#   'it',
#   'really',
#   'well',
#   'directed'],
#  ['punitively', 'affirmational', 'parable'],
#  ['demme',
#   'finally',
#   'succeeds',
#   'in',
#   'diminishing',
#   'his',
#   'stature',
#   'from',
#   'oscar-winning',
#   'master',
#   'to',
#   'lowly',
#   'studio',
#   'hack'],
#  ['horrid',
#   'little',
#   'propaganda',
#   'film',
#   'with',
#   'fascinating',
#   u'connection',
#   'not',
#   'only',
#   'to',
#   'the',
#   u'serb',
#   'themselves',
#   'but',
#   'also',
#   'to',
#   'a',
#   'network',
#   'of',
#   'american',
#   'right-wing',
#   u'extremist'],
#  ['star\\/producer',
#   'salma',
#   'hayek',
#   'and',
#   'director',
#   'julie',
#   'taymor',
#   'have',
#   'infused',
#   'frida',
#   'with',
#   'a',
#   'visual',
#   'style',
#   'unique',
#   'and',
#   'inherent',
#   'to',
#   'the',
#   'titular',
#   'character',
#   u'painting',
#   'and',
#   'in',
#   'the',
#   'process',
#   'created',
#   'a',
#   'masterful',
#   'work',
#   'of',
#   'art',
#   'of',
#   'their',
#   'own'],
#  ['this', 'one', 'is', 'not', 'nearly', u'a', 'dreadful', u'a', 'expected'],
#  ['but',
#   '...',
#   'in',
#   'trying',
#   'to',
#   'capture',
#   'the',
#   'novel',
#   'deeper',
#   'intimate',
#   u'resonance',
#   'the',
#   'film',
#   u'ha',
#   'ironically',
#   '-',
#   'distanced',
#   u'u',
#   'from',
#   'the',
#   u'character'],
#  ['real',
#   u'woman',
#   'have',
#   u'curve',
#   u'wear',
#   u'it',
#   'empowerment',
#   'on',
#   u'it',
#   'sleeve',
#   'but',
#   'even',
#   u'it',
#   'worst',
#   u'harangue',
#   'are',
#   'easy',
#   'to',
#   'swallow',
#   'thanks',
#   'to',
#   'remarkable',
#   u'performance',
#   'by',
#   'ferrera',
#   'and',
#   'ontiveros'],
#  ['there',
#   'a',
#   'whole',
#   'heap',
#   'of',
#   'nothing',
#   'at',
#   'the',
#   'core',
#   'of',
#   'this',
#   'slight',
#   'coming-of-age\\/coming-out',
#   'tale'],
#  ['a', 'sensitive', 'moving', 'brilliantly', 'constructed', 'work'],
#  ['it',
#   u'pull',
#   'the',
#   'rug',
#   'out',
#   'from',
#   'under',
#   'you',
#   'just',
#   'when',
#   'you',
#   "'re",
#   'ready',
#   'to',
#   'hate',
#   'one',
#   'character',
#   'or',
#   'really',
#   'sympathize',
#   'with',
#   'another',
#   'character',
#   'something',
#   'happens',
#   'to',
#   'send',
#   'you',
#   'off',
#   'in',
#   'different',
#   'direction'],
#  ['the',
#   'art',
#   'direction',
#   'is',
#   'often',
#   'exquisite',
#   'and',
#   'the',
#   'anthropomorphic',
#   'animal',
#   u'character',
#   'are',
#   'beautifully',
#   'realized',
#   'through',
#   'clever',
#   'makeup',
#   'design',
#   'leaving',
#   'one',
#   'to',
#   'hope',
#   'that',
#   'the',
#   'eventual',
#   'dvd',
#   'release',
#   'will',
#   'offer',
#   u'subtitle',
#   'and',
#   'the',
#   'original',
#   'italian-language',
#   'soundtrack'],
#  ['it',
#   'probably',
#   'not',
#   'easy',
#   'to',
#   'make',
#   'such',
#   'a',
#   'worthless',
#   'film',
#   '...'],
#  ['the',
#   'creative',
#   'animation',
#   'work',
#   'may',
#   'not',
#   'look',
#   u'a',
#   'fully',
#   'rendered',
#   u'a',
#   'pixar',
#   'industry',
#   'standard',
#   'but',
#   'it',
#   u'us',
#   'lighting',
#   u'effect',
#   'and',
#   'innovative',
#   u'background',
#   'to',
#   'an',
#   'equally',
#   'impressive',
#   'degree'],
#  ['an', 'often', 'unfunny', 'romp'],
#  ['it',
#   u'make',
#   'sense',
#   'that',
#   'he',
#   'went',
#   'back',
#   'to',
#   'school',
#   'to',
#   'check',
#   'out',
#   'the',
#   u'girl',
#   'his',
#   'film',
#   'is',
#   'a',
#   'frat',
#   'boy',
#   'idea',
#   'of',
#   'a',
#   'good',
#   'time'],
#  ['clever', 'but', 'not', 'especially', 'compelling'],
#  ['an', 'exit', 'sign', 'that', 'is'],
#  ['it',
#   'an',
#   'actor',
#   'showcase',
#   'that',
#   'accomplishes',
#   u'it',
#   'primary',
#   'goal',
#   'without',
#   'the',
#   'use',
#   'of',
#   'special',
#   u'effect',
#   'but',
#   'rather',
#   'by',
#   'emphasizing',
#   'the',
#   u'character',
#   'including',
#   'the',
#   'supporting',
#   u'one'],
#  ['the',
#   'emperor',
#   'club',
#   'ruthless',
#   'in',
#   u'it',
#   'own',
#   'placid',
#   'way',
#   u'find',
#   'one',
#   'of',
#   'our',
#   'most',
#   'conservative',
#   'and',
#   'hidebound',
#   'movie-making',
#   u'tradition',
#   'and',
#   u'give',
#   'it',
#   'new',
#   'texture',
#   'new',
#   'relevance',
#   'new',
#   'reality'],
#  ['...',
#   'if',
#   'it',
#   'had',
#   'been',
#   'only',
#   'half-an-hour',
#   'long',
#   'or',
#   'a',
#   'tv',
#   'special',
#   'the',
#   'humor',
#   'would',
#   'have',
#   'been',
#   'fast',
#   'and',
#   'furious',
#   'at',
#   'ninety',
#   u'minute',
#   'it',
#   u'drag'],
#  [u'it',
#   'compelling',
#   'mix',
#   'of',
#   'trial',
#   'movie',
#   'escape',
#   'movie',
#   'and',
#   'unexpected',
#   'fable',
#   'ensures',
#   'the',
#   'film',
#   'never',
#   u'feel',
#   'draggy'],
#  ['it', 'drowns', 'in', 'sap'],
#  ['rare',
#   u'bird',
#   u'try',
#   'to',
#   'force',
#   u'it',
#   'quirkiness',
#   'upon',
#   'the',
#   'audience'],
#  ['a',
#   'solid',
#   'and',
#   'refined',
#   'piece',
#   'of',
#   'moviemaking',
#   'imbued',
#   'with',
#   'passion',
#   'and',
#   'attitude'],
#  ['red', 'dragon', 'never', u'cut', u'corner'],
#  ['modeled'],
#  ['alternative',
#   'medicine',
#   'obviously',
#   u'ha',
#   u'it',
#   u'merit',
#   '...',
#   'but',
#   'ayurveda',
#   u'doe',
#   'the',
#   'field',
#   'no',
#   u'favor'],
#  ['bland', 'but', 'harmless'],
#  [u'viewer',
#   'are',
#   'asked',
#   'so',
#   'often',
#   'to',
#   'suspend',
#   'belief',
#   'that',
#   'were',
#   'it',
#   'not',
#   'for',
#   'holm',
#   'performance',
#   'the',
#   'film',
#   'would',
#   'be',
#   'a',
#   'total',
#   'washout'],
#  ['a',
#   'small',
#   'fortune',
#   'in',
#   u'salary',
#   'and',
#   'stunt',
#   u'car',
#   'might',
#   'have',
#   'been',
#   'saved',
#   'if',
#   'the',
#   'director',
#   'tom',
#   'dey',
#   'had',
#   'spliced',
#   'together',
#   u'bit',
#   'and',
#   u'piece',
#   'of',
#   'midnight',
#   'run',
#   'and',
#   '48',
#   u'hour',
#   '-lrb-',
#   'and',
#   'for',
#   'that',
#   'matter',
#   'shrek',
#   '-rrb-'],
#  ['it',
#   'good',
#   'to',
#   'see',
#   'michael',
#   'caine',
#   'whipping',
#   'out',
#   'the',
#   'dirty',
#   u'word',
#   'and',
#   'punching',
#   'people',
#   'in',
#   'the',
#   'stomach',
#   'again'],
#  ['no',
#   'such',
#   'thing',
#   u'break',
#   'no',
#   'new',
#   'ground',
#   'and',
#   u'tread',
#   'old',
#   'turf',
#   'like',
#   'a',
#   'hippopotamus',
#   'ballerina'],
#  ['the',
#   'film',
#   'exudes',
#   'the',
#   'urbane',
#   'sweetness',
#   'that',
#   'woody',
#   'allen',
#   'seems',
#   'to',
#   'have',
#   'bitterly',
#   'forsaken'],
#  ['the',
#   'script',
#   'is',
#   'a',
#   'dim-witted',
#   'pairing',
#   'of',
#   'teen-speak',
#   'and',
#   'animal',
#   'gibberish'],
#  ['cedar',
#   'somewhat',
#   'defuses',
#   'this',
#   'provocative',
#   'theme',
#   'by',
#   'submerging',
#   'it',
#   'in',
#   'a',
#   'hoary',
#   'love',
#   'triangle'],
#  ['what',
#   'might',
#   'have',
#   'emerged',
#   u'a',
#   'hilarious',
#   'lunacy',
#   'in',
#   'the',
#   u'hand',
#   'of',
#   'woody',
#   'allen',
#   'or',
#   'mel',
#   u'brook',
#   '-lrb-',
#   'at',
#   'least',
#   'during',
#   'their',
#   "'70s",
#   'heyday',
#   '-rrb-',
#   u'come',
#   'across',
#   u'a',
#   'lame',
#   'and',
#   'sophomoric',
#   'in',
#   'this',
#   'debut',
#   'indie',
#   'feature'],
#  ['i',
#   'have',
#   'not',
#   'been',
#   'this',
#   'disappointed',
#   'by',
#   'a',
#   'movie',
#   'in',
#   'a',
#   'long',
#   'time'],
#  ['there',
#   'not',
#   'a',
#   'comedic',
#   'moment',
#   'in',
#   'this',
#   'romantic',
#   'comedy'],
#  ['i',
#   'admire',
#   'it',
#   'and',
#   'yet',
#   'can',
#   'not',
#   'recommend',
#   'it',
#   'because',
#   'it',
#   'overstays',
#   u'it',
#   'natural',
#   'running',
#   'time'],
#  ['there',
#   'plenty',
#   'to',
#   'enjoy',
#   'in',
#   'no',
#   'small',
#   'part',
#   'thanks',
#   'to',
#   'lau'],
#  ['action', '-', 'mechanical'],
#  ...]

# %% [markdown]
# *************************************

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(np.array(raw_train_data['Tokens']),
                np.array(raw_train_data['Sentiment']), test_size=0.2)

# %% [markdown]
# Training set: 80% Validation set: 20%

# %%
from gensim.models.doc2vec import LabeledSentence

def labelize(phrase, label_type):
    labelized = []
    for i,v in enumerate(phrase):
        label = '%s:%s'%(label_type,i)
        labelized.append(LabeledSentence(v, [label]))
    return labelized

x_train = labelize(x_train, 'TRAIN')
x_test = labelize(x_test, 'TEST')
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Before feeding the tokens into a Word2Vec model, I've labeled the tokens according to whether they belong to the training or testing/validation set, and which phrase they belong to(a.k.a their PhraseId). I've done this using the LabeledSentence feature from doc2vec.
#
# The format of a LabeledSentence can be observed below:

# %%
x_train[2]
# Out:
# TaggedDocument(words=['well-timed'], tags=['TRAIN:2'])

# %%
from gensim.models import Word2Vec

phrase_w2v = Word2Vec(size=100,min_count=15)
phrase_w2v.build_vocab([x.words for x in x_train])
phrase_w2v.train([x.words for x in x_train],total_examples = phrase_w2v.corpus_count,epochs=phrase_w2v.iter)
# Out:
# 2858636

# %% [markdown]
# Using Word2Vec, I created and trained a model on the tokens of the training data. In a gist, Word2Vec creates a neural network which converts tokens into numerical vectors. These vectors(also called embeddings) can be fed into a neural network and be used to classify based on sentiment. The sum and/or difference between these vectors carry great meaning, which I've demonstrated below. Embeddings whose associated tokens carry similar meaning are generally clustered closer to each other, and vice versa.
#
# I assigned the size in the model as 150, which basically defines the degrees of freedom, or roughly, the number of nodes in the model. Also, words fed into the model whose frequency in the data is less than 10 is ignored.
#
# The embedding for the word 'nice' can be observed below:

# %%
phrase_w2v['nice']
# Out:
# array([ 0.19460882,  0.28304538, -0.61726165,  0.37004191, -0.38983616,
#         0.07368344, -0.112293  , -0.3897855 , -0.01932672,  0.03445116,
#         0.09232974, -0.35326639, -0.8649289 , -0.52771729,  0.19727595,
#         0.0673535 ,  0.14198816, -0.363958  , -0.2865566 ,  0.37852663,
#        -0.15528062, -0.45139265,  0.20274448,  0.30404374,  0.20228182,
#        -0.24016073,  0.19889098,  0.07369884, -0.00460604, -0.22074097,
#         0.10692782, -0.18536924,  0.02890042,  0.06732693,  0.09263849,
#         0.17172091, -0.27688554,  0.1678309 , -0.11267179, -0.24626803,
#        -0.4167293 , -0.14301038, -0.48494792,  0.21648701, -0.1683933 ,
#        -0.40129712,  0.15611519,  0.08161563,  0.11157811, -0.19134447,
#        -0.05413804, -0.39912054, -0.17793643, -0.1595394 ,  0.23436823,
#        -0.15852636,  0.1083882 , -0.02082567,  0.03220307,  0.15224835,
#         0.22336291,  0.26339245, -0.05817559, -0.18589264, -0.16482267,
#         0.26765487,  0.07558876, -0.43818974,  0.07203849, -0.07702889,
#        -0.33466005, -0.30957526, -0.21467294,  0.61767483, -0.20615314,
#        -0.35085323,  0.47579199,  0.31948501,  0.3120333 ,  0.1096583 ,
#         0.22245795,  0.10502531, -0.11889262,  0.09494701,  0.10385468,
#         0.29764166, -0.20143248, -0.28604609,  0.30893937, -0.49627659,
#        -0.46051067,  0.10341682,  0.09653867,  0.26242834, -0.03590347,
#        -0.04897326,  0.39463568,  0.28345776,  0.3539367 , -0.18227695], dtype=float32)

# %%
#A fun demonstration of the power of Word2Vec
print "Words similar to boring: " + str(phrase_w2v.most_similar('boring'))
print "Words similar to fun: " + str(phrase_w2v.most_similar('fun'))
print "Words similar to amazing: " + str(phrase_w2v.most_similar('amazing'))
print "Words similar to exciting: " + str(phrase_w2v.most_similar('exciting'))
# Out:
# Words similar to boring: [('stupid', 0.8793920874595642), ('seriously', 0.8413165807723999), ('unconventional', 0.8391678333282471), ('awful', 0.813866376876831), ('damn', 0.8115553855895996), (u'canadian', 0.798823356628418), ('upbeat', 0.7988153100013733), ('painfully', 0.7957883477210999), ('badly', 0.790155827999115), ('convincingly', 0.7864308953285217)]
# Words similar to fun: [('premise', 0.7460943460464478), ('very', 0.7326239347457886), ('neither', 0.727053165435791), ('deal', 0.7233792543411255), ('yarn', 0.6851993799209595), ('really', 0.6828815937042236), ('pretty', 0.6822550296783447), (u'intention', 0.677566647529602), ('important', 0.6713937520980835), ('case', 0.6636844277381897)]
# Words similar to amazing: [('ramsay', 0.9167611002922058), ('unforced', 0.905788779258728), ('enigma', 0.9057779312133789), ('walsh', 0.9028055667877197), ('achievement', 0.9017120599746704), ('barry', 0.901654839515686), ('top-billed', 0.9006106853485107), ('impressive', 0.900441586971283), ('nicholson', 0.8988628387451172), (u'comment', 0.8979634046554565)]
# Words similar to exciting: [('inspirational', 0.9120947122573853), ('inspiring', 0.9070043563842773), ('overwritten', 0.8969261646270752), ('institution', 0.895877480506897), ('incredibly', 0.8913931846618652), ('equally', 0.8849126100540161), ('labored', 0.8842455148696899), ('parable', 0.8826574683189392), ('stilted', 0.8799368739128113), ('undeniably', 0.8787624835968018)]

# %% [markdown]
# We can see that words similar to boring can be detected using the model. For example, it is surprising to observe that the model is able to recognize that boring and tedious are similar, amazing and surreal are similar, etc. Of course there are some weird exceptions, but we can see that some words bear a certain resemblance.

# %%
from sklearn.manifold import TSNE

plt.figure(figsize=(9,9))

X = phrase_w2v[phrase_w2v.wv.vocab]

tsne = TSNE(n_components=2)
X_tsne = tsne.fit_transform(X)

plt.scatter(X_tsne[:, 0], X_tsne[:, 1])

plt.show()

# %% [markdown]
# A tSNE graph, or a t-distributed stochastic neighbor embedding graph, maps all the embeddings in the model down to a two dimensional space. It can be observed that there are certain clusterings of different embeddings. The embeddings which are closer together(smaller Euclidean distance) bear more similarity in meaning to one another.

# %% [markdown]
# ***********************************

# %% [markdown]
# ## Data Preprocessing

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(analyzer=lambda x: x, min_df=10)
matrix = vectorizer.fit_transform([x.words for x in x_train])
tfidf = dict(zip(vectorizer.get_feature_names(), vectorizer.idf_))
print 'vocab size :', len(tfidf)
# Out:
# vocab size : 8750

# %% [markdown]
# The first step of preprocessing is to convert these word vectors into phrase vectors. There are a few methods of doing this(using simple sum of vectors, average of vectors, feeding the vectors into an LSTM network,etc.). The method I've gone with is a weighted average of word embeddings. The weights of each word embedding are its TF-IDF value.
#
# The TF-IDF (Term Frequency,Inverse Document Frequency) method of weighting has a simple intuition. If a word appears more in a phrase(term frequency), it is important for the sentiment, however, if the word appears more overall across all phrases(document frequency), it should be given less importance. Combining these two, a TF-IDF weight can be assigned to all word vectors, and a weighted average can be carried out.

# %%
def buildPhraseVector(tokens, size):
    vec = np.zeros(size).reshape((1, size))
    count = 0.
    for word in tokens:
        try:
            vec += phrase_w2v[word].reshape((1, size)) * tfidf[word]
            count += 1.
        except KeyError: # handling the case where the token is not
                         # in the corpus. useful for testing.
            continue
    if count != 0:
        vec /= count
    return vec

# %% [markdown]
# I've created a weighting average function in the above step to generate phrase vectors.

# %%
from sklearn.preprocessing import scale
train_vecs_w2v = np.concatenate([buildPhraseVector(z, 100) for z in map(lambda x: x.words, x_train)])
train_vecs_w2v = scale(train_vecs_w2v)

test_vecs_w2v = np.concatenate([buildPhraseVector(z, 100) for z in map(lambda x: x.words, x_test)])
test_vecs_w2v = scale(test_vecs_w2v)

# %% [markdown]
# I've scaled the phrase vectors down to allow for smooth training.

# %%
import keras

# One-hot encoding the labels
num_classes = 5
y_train = keras.utils.to_categorical(y_train, num_classes)
print(y_train.shape)

# One-hot encoding the labels
num_classes = 5
y_test = keras.utils.to_categorical(y_test, num_classes)
print(y_test.shape)
# Out:
# (124848, 5)
# (31212, 5)

# %% [markdown]
# I've one-hot encoded the labels to be used in the Keras neural network.

# %% [markdown]
# ## Model Selection and Training

# %% [markdown]
# The following model that I've created was a result of intuitive trial-and-error. I've created a fully-connected neural network with appropriate dropouts to prevent overfitting. My intuition was as follows:
# - The more the degrees of freedom in the Word2Vec model(or the larger the word vector), the more number of nodes(the more deeper) the neural net.
# - When moving from one hidden layer to the next, try to maintain a steady drop in nodes.(e.g. if layer 1 has 512 nodes, layer 2 should have 256 rather than 16 nodes)
# - Assign dropout to only those layers with a larger number of nodes(below 128). Assigning dropout to layers with smaller number of nodes will only create improper training of that layer.

# %%
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.callbacks import ModelCheckpoint

model = Sequential()


model.add(Dense(256, activation='relu',input_dim=100))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu',input_dim=100))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 256)               25856
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 67,333
# Trainable params: 67,333
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compiling the model
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['categorical_accuracy'])

# %% [markdown]
# Compiled the model with the loss as categorical cross-entropy since we are doing multi-class classification.

# %%
checkpointer = ModelCheckpoint(filepath='weights.best.hdf5', verbose=1, save_best_only=True)

# %% [markdown]
# I've saved the best weights with respect to the validation accuracy using ModelCheckpoint.

# %%
# Running and evaluating the model
model.fit(train_vecs_w2v, y_train, epochs=20, batch_size=32,validation_data=(test_vecs_w2v,y_test), callbacks=[checkpointer],verbose=1)
# Out:
# Train on 124848 samples, validate on 31212 samples
# Epoch 1/20
# 124576/124848 [============================>.] - ETA: 0s - loss: 1.3288 - categorical_accuracy: 0.5541Epoch 00000: val_loss did not improve
# 124848/124848 [==============================] - 13s - loss: 1.3289 - categorical_accuracy: 0.5541 - val_loss: 1.2908 - val_categorical_accuracy: 0.5604
# Epoch 2/20
# 124640/124848 [============================>.] - ETA: 0s - loss: 1.3570 - categorical_accuracy: 0.5534Epoch 00001: val_loss did not improve
# 124848/124848 [==============================] - 13s - loss: 1.3573 - categorical_accuracy: 0.5534 - val_loss: 1.2576 - val_categorical_accuracy: 0.5623
# Epoch 3/20
# 124608/124848 [============================>.] - ETA: 0s - loss: 1.3766 - categorical_accuracy: 0.5552Epoch 00002: val_loss did not improve
# 124848/124848 [==============================] - 13s - loss: 1.3768 - categorical_accuracy: 0.5551 - val_loss: 1.3506 - val_categorical_accuracy: 0.5609
# Epoch 4/20
# 124736/124848 [============================>.] - ETA: 0s - loss: 1.4210 - categorical_accuracy: 0.5576Epoch 00003: val_loss did not improve
# 124848/124848 [==============================] - 13s - loss: 1.4210 - categorical_accuracy: 0.5576 - val_loss: 1.3188 - val_categorical_accuracy: 0.5574
# Epoch 5/20
# 124736/124848 [============================>.] - ETA: 0s - loss: 1.4424 - categorical_accuracy: 0.5543Epoch 00004: val_loss did not improve
# 124848/124848 [==============================] - 14s - loss: 1.4423 - categorical_accuracy: 0.5543 - val_loss: 1.4545 - val_categorical_accuracy: 0.5548
# Epoch 6/20
# 124608/124848 [============================>.] - ETA: 0s - loss: 1.4581 - categorical_accuracy: 0.5556Epoch 00005: val_loss did not improve
# 124848/124848 [==============================] - 14s - loss: 1.4576 - categorical_accuracy: 0.5557 - val_loss: 1.4960 - val_categorical_accuracy: 0.5602
# Epoch 7/20
# 124416/124848 [============================>.] - ETA: 0s - loss: 1.5100 - categorical_accuracy: 0.5581Epoch 00006: val_loss did not improve
# 124848/124848 [==============================] - 13s - loss: 1.5102 - categorical_accuracy: 0.5581 - val_loss: 1.4860 - val_categorical_accuracy: 0.5620
# Epoch 8/20
# 124512/124848 [============================>.] - ETA: 0s - loss: 1.4829 - categorical_accuracy: 0.5586Epoch 00007: val_loss did not improve
# 124848/124848 [==============================] - 13s - loss: 1.4827 - categorical_accuracy: 0.5586 - val_loss: 1.3925 - val_categorical_accuracy: 0.5629
# Epoch 9/20
# 124576/124848 [============================>.] - ETA: 0s - loss: 1.5895 - categorical_accuracy: 0.5573Epoch 00008: val_loss did not improve
# 124848/124848 [==============================] - 14s - loss: 1.5894 - categorical_accuracy: 0.5573 - val_loss: 1.5005 - val_categorical_accuracy: 0.5500
# Epoch 10/20
# 124480/124848 [============================>.] - ETA: 0s - loss: 1.6345 - categorical_accuracy: 0.5576Epoch 00009: val_loss did not improve
# 124848/124848 [==============================] - 16s - loss: 1.6337 - categorical_accuracy: 0.5579 - val_loss: 1.5229 - val_categorical_accuracy: 0.5569
# Epoch 11/20
# 124704/124848 [============================>.] - ETA: 0s - loss: 1.5910 - categorical_accuracy: 0.5590Epoch 00010: val_loss did not improve
# 124848/124848 [==============================] - 15s - loss: 1.5910 - categorical_accuracy: 0.5590 - val_loss: 1.5025 - val_categorical_accuracy: 0.5556
# Epoch 12/20
# 124672/124848 [============================>.] - ETA: 0s - loss: 1.5496 - categorical_accuracy: 0.5592Epoch 00011: val_loss did not improve
# 124848/124848 [==============================] - 15s - loss: 1.5501 - categorical_accuracy: 0.5592 - val_loss: 1.4673 - val_categorical_accuracy: 0.5667
# Epoch 13/20
# 124768/124848 [============================>.] - ETA: 0s - loss: 1.5230 - categorical_accuracy: 0.5603Epoch 00012: val_loss did not improve
# 124848/124848 [==============================] - 15s - loss: 1.5229 - categorical_accuracy: 0.5603 - val_loss: 1.4900 - val_categorical_accuracy: 0.5629
# Epoch 14/20
# 124384/124848 [============================>.] - ETA: 0s - loss: 1.5714 - categorical_accuracy: 0.5594Epoch 00013: val_loss did not improve
# 124848/124848 [==============================] - 16s - loss: 1.5715 - categorical_accuracy: 0.5594 - val_loss: 1.5374 - val_categorical_accuracy: 0.5584
# Epoch 15/20
# 124544/124848 [============================>.] - ETA: 0s - loss: 1.5711 - categorical_accuracy: 0.5598Epoch 00014: val_loss did not improve
# 124848/124848 [==============================] - 14s - loss: 1.5710 - categorical_accuracy: 0.5597 - val_loss: 1.4878 - val_categorical_accuracy: 0.5633
# Epoch 16/20
# 124480/124848 [============================>.] - ETA: 0s - loss: 1.5916 - categorical_accuracy: 0.5602Epoch 00015: val_loss did not improve
# 124848/124848 [==============================] - 15s - loss: 1.5924 - categorical_accuracy: 0.5601 - val_loss: 1.5975 - val_categorical_accuracy: 0.5594
# Epoch 17/20
# 124544/124848 [============================>.] - ETA: 0s - loss: 1.5702 - categorical_accuracy: 0.5595Epoch 00016: val_loss did not improve
# 124848/124848 [==============================] - 13s - loss: 1.5700 - categorical_accuracy: 0.5595 - val_loss: 1.5639 - val_categorical_accuracy: 0.5672
# Epoch 18/20
# 124448/124848 [============================>.] - ETA: 0s - loss: 1.5722 - categorical_accuracy: 0.5608Epoch 00017: val_loss did not improve
# 124848/124848 [==============================] - 13s - loss: 1.5725 - categorical_accuracy: 0.5607 - val_loss: 1.5096 - val_categorical_accuracy: 0.5632
# Epoch 19/20
# 124384/124848 [============================>.] - ETA: 0s - loss: 1.6040 - categorical_accuracy: 0.5604Epoch 00018: val_loss did not improve
# 124848/124848 [==============================] - 15s - loss: 1.6039 - categorical_accuracy: 0.5603 - val_loss: 1.5003 - val_categorical_accuracy: 0.5598
# Epoch 20/20
# 124384/124848 [============================>.] - ETA: 0s - loss: 1.5824 - categorical_accuracy: 0.5611Epoch 00019: val_loss did not improve
# 124848/124848 [==============================] - 13s - loss: 1.5823 - categorical_accuracy: 0.5612 - val_loss: 1.5002 - val_categorical_accuracy: 0.5675

# %% [markdown]
# ## Model Evaluation

# %%
score = model.evaluate(test_vecs_w2v, y_test, batch_size=128, verbose=2)
print score[1]
# Out:
# 0.567474048489

# %% [markdown]
# The categorical accuracy of 56.7% that I achieved was after a lot of testing of different models. The accuracy is not as high as I expected it to be. However, my intuition was sound and it allowed me to achieve the best accuracy despite the limitations of my approach.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# The model does a decent job of multi-class classification, but there is still a whole lot of room for improvement.
#
# The limitations of my approach were:
# - I used an averaging method to generate a phrase vector. A much more effective way of doing so would be to use an LSTM Network and feed the word vectors into it.
# - The data itself was not adequate for my method to work well. Total number of sentences(not phrases) were 8544, which is hardly enough to train a robust word2vec model.
# - I might not have done sufficient pre-processing. I had also tried removing stop words(Common words like 'a','the',etc.) and then testing the model, but it turns out, there is a very frustrating tradeoff between boosting the effectiveness of the word2vec model, and boosting the effectiveness of the Keras neural network. Removing the stop-words would have made classification much more accurate, but it led to a loss in context, leading to a drop in accuracy for the word2vec model.
# - I did not incorporate the use of any recurrent node network(RNN,LSTM,GRU) for classification. A memory model may have been more effective in classification, given that it has a capability for remembering previous input.
